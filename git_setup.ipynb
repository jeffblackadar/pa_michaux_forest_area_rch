# %%
import os
os.chdir('/content/drive/MyDrive/crane_maryland/maryland_rch/')
# !pwd
# !git init .
# Out:
# /content/drive/MyDrive/crane_maryland/maryland_rch
# Initialized empty Git repository in /content/drive/MyDrive/crane_maryland/maryland_rch/.git/

# %%
import os
os.chdir('/content/drive/MyDrive/crane_maryland/maryland_rch/')
# !pwd
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-6e2ffafac6a4> in <module>()
#       1 import os
# ----> 2 os.chdir('/content/drive/MyDrive/crane_maryland/maryland_rch/')
#       3 get_ipython().system('pwd')
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/MyDrive/crane_maryland/maryland_rch/'

# %%
# !git add -A
# Out:
# fatal: not a git repository (or any of the parent directories): .git

# %%
# !git commit -m "4 commit"
# Out:
# On branch master
#
# Initial commit
#
# nothing to commit

# %%
# !git branch -m master main

# %%
# !git remote add origin https://**PAT**@github.com/jeffblackadar/maryland_rch.git

# %%
# !git pull
# Out:
# There is no tracking information for the current branch.
# Please specify which branch you want to merge with.
# See git-pull(1) for details.
#
#     git pull <remote> <branch>
#
# If you wish to set tracking information for this branch you can do so with:
#
#     git branch --set-upstream-to=origin/<branch> main

# %%
# !git push origin main
# Out:
# Everything up-to-date

# %%
# !git status
# Out:
# On branch main
# nothing to commit, working tree clean

# %%
# !git config http.postBuffer 524288000

# %%
# !git pull origin main --allow-unrelated-histories
# Out:
# From https://github.com/jeffblackadar/maryland_rch
#  * branch            main       -> FETCH_HEAD
# Already up to date.

# %%
# !git reset --hard
# Out:
# HEAD is now at a5f6c55 3 commit

# %%
# !git push --help

# %%
# !git --version
# Out:
# git version 2.17.1
