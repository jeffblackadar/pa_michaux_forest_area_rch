# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/crane_maryland
# !mkdir /content/drive/MyDrive/crane_maryland/mask-rcnn-repository
# Out:
# /content/drive/MyDrive/crane_maryland
# mkdir: cannot create directory ‘/content/drive/MyDrive/crane_maryland/mask-rcnn-repository’: File exists

# %%
# !mkdir /content/drive/MyDrive/crane_maryland/predictions

# %%
# !mkdir /content/drive/MyDrive/crane_maryland/polys

# %%
# %cd /content/drive/MyDrive/crane_maryland/mask-rcnn-repository
# Out:
# /content/drive/MyDrive/crane_maryland/mask-rcnn-repository

# %%
# !git clone https://github.com/matterport/Mask_RCNN.git
# Out:
# fatal: destination path 'Mask_RCNN' already exists and is not an empty directory.

# %%
#Thanks to https://emadehsan.com/p/object-detection
# %cd /content/drive/MyDrive/crane_maryland/mask-rcnn-repository/Mask_RCNN
# !python setup.py install
# Out:
# /content/drive/MyDrive/crane_maryland/mask-rcnn-repository/Mask_RCNN
# WARNING:root:Fail load requirements file, so using default ones.
# /usr/local/lib/python3.7/dist-packages/setuptools/dist.py:700: UserWarning: Usage of dash-separated 'description-file' will not be supported in future versions. Please use the underscore name 'description_file' instead
#   % (opt, underscore_opt))
# /usr/local/lib/python3.7/dist-packages/setuptools/dist.py:700: UserWarning: Usage of dash-separated 'license-file' will not be supported in future versions. Please use the underscore name 'license_file' instead
#   % (opt, underscore_opt))
# /usr/local/lib/python3.7/dist-packages/setuptools/dist.py:700: UserWarning: Usage of dash-separated 'requirements-file' will not be supported in future versions. Please use the underscore name 'requirements_file' instead
#   % (opt, underscore_opt))
# running install
# running bdist_egg
# running egg_info
# writing mask_rcnn.egg-info/PKG-INFO
# writing dependency_links to mask_rcnn.egg-info/dependency_links.txt
# writing top-level names to mask_rcnn.egg-info/top_level.txt
# reading manifest template 'MANIFEST.in'
# adding license file 'LICENSE'
# writing manifest file 'mask_rcnn.egg-info/SOURCES.txt'
# installing library code to build/bdist.linux-x86_64/egg
# running install_lib
# running build_py
# creating build/bdist.linux-x86_64/egg
# creating build/bdist.linux-x86_64/egg/mrcnn
# copying build/lib/mrcnn/visualize.py -> build/bdist.linux-x86_64/egg/mrcnn
# copying build/lib/mrcnn/parallel_model.py -> build/bdist.linux-x86_64/egg/mrcnn
# copying build/lib/mrcnn/utils.py -> build/bdist.linux-x86_64/egg/mrcnn
# copying build/lib/mrcnn/config.py -> build/bdist.linux-x86_64/egg/mrcnn
# copying build/lib/mrcnn/__init__.py -> build/bdist.linux-x86_64/egg/mrcnn
# copying build/lib/mrcnn/model.py -> build/bdist.linux-x86_64/egg/mrcnn
# byte-compiling build/bdist.linux-x86_64/egg/mrcnn/visualize.py to visualize.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mrcnn/parallel_model.py to parallel_model.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mrcnn/utils.py to utils.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mrcnn/config.py to config.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mrcnn/__init__.py to __init__.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mrcnn/model.py to model.cpython-37.pyc
# creating build/bdist.linux-x86_64/egg/EGG-INFO
# copying mask_rcnn.egg-info/PKG-INFO -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying mask_rcnn.egg-info/SOURCES.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying mask_rcnn.egg-info/dependency_links.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying mask_rcnn.egg-info/top_level.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# zip_safe flag not set; analyzing archive contents...
# creating 'dist/mask_rcnn-2.1-py3.7.egg' and adding 'build/bdist.linux-x86_64/egg' to it
# removing 'build/bdist.linux-x86_64/egg' (and everything under it)
# Processing mask_rcnn-2.1-py3.7.egg
# Copying mask_rcnn-2.1-py3.7.egg to /usr/local/lib/python3.7/dist-packages
# Adding mask-rcnn 2.1 to easy-install.pth file
#
# Installed /usr/local/lib/python3.7/dist-packages/mask_rcnn-2.1-py3.7.egg
# Processing dependencies for mask-rcnn==2.1
# Finished processing dependencies for mask-rcnn==2.1

# %%
# !pip install 'h5py<3.0.0'
# Out:
# Collecting h5py<3.0.0
#   Downloading h5py-2.10.0-cp37-cp37m-manylinux1_x86_64.whl (2.9 MB)
#      |████████████████████████████████| 2.9 MB 5.1 MB/s
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from h5py<3.0.0) (1.15.0)
# Requirement already satisfied: numpy>=1.7 in /usr/local/lib/python3.7/dist-packages (from h5py<3.0.0) (1.19.5)
# Installing collected packages: h5py
#   Attempting uninstall: h5py
#     Found existing installation: h5py 3.1.0
#     Uninstalling h5py-3.1.0:
#       Successfully uninstalled h5py-3.1.0
# Successfully installed h5py-2.10.0

# %%
import os
import sys
# Root directory of the project
ROOT_D = os.path.abspath("./content/drive/MyDrive/crane_maryland/mask-rcnn-repository/Mask_RCNN")

# Import Mask RCNN
sys.path.append(ROOT_D)

# %%
# Write Annot
def write_annot(obj_type, obj_annots_dir, obj_f_num, org_f_name, org_f_path,org_f_width,org_f_height,org_f_depth, refPts, scores):
    # With credit to: 
    # https://www.geeksforgeeks.org/reading-writing-text-files-python/
    annot_file_path = obj_annots_dir+obj_f_num+'.xml'
    annot_file = open(annot_file_path,"w") 

    annot_file.write("<annotation>\n") 
    annot_file.write("	<folder>"+obj_type+"</folder>\n") 
    annot_file.write("	<filename>"+org_f_name+"</filename>\n") 
    annot_file.write("	<path>"+org_f_path+"</path>\n") 
    annot_file.write("	<source>\n") 
    annot_file.write("		<database>Muhlenberg_charcoal_hearths</database>\n") 
    annot_file.write("	</source>\n") 
    annot_file.write("	<size>\n") 
    annot_file.write("		<width>"+str(org_f_width)+"</width>\n") 
    annot_file.write("		<height>"+str(org_f_height)+"</height>\n") 
    annot_file.write("		<depth>"+str(org_f_depth)+"</depth>\n") 
    annot_file.write("	</size>\n")
    annot_file.write("	<!-- <object_present>0 = the object is not present in the image. 1 = it is -->\n")
    annot_file.write("	<object_present>0</object_present>\n")    
    for ocn in range(0,len(refPts)):
        refPt = refPts[ocn]
        refPtMin = refPt[0]
        refPtMax = refPt[1]
        annot_file.write("	<object>\n") 
        annot_file.write("		<name>"+obj_type+"</name>\n") 
        annot_file.write("		<number>"+str(ocn)+"</number>\n") 
        annot_file.write("		<score>"+str(scores[ocn])+"</score>\n")
        annot_file.write("		<correct>0</correct>\n")
        annot_file.write("		<bndbox>\n") 
        annot_file.write("			<xmin>"+str(refPtMin[0])+"</xmin>\n") 
        annot_file.write("			<ymin>"+str(refPtMin[1])+"</ymin>\n") 
        annot_file.write("			<xmax>"+str(refPtMax[0])+"</xmax>\n") 
        annot_file.write("			<ymax>"+str(refPtMax[1])+"</ymax>\n") 
        annot_file.write("		</bndbox>\n") 
        annot_file.write("	</object>\n") 
    annot_file.write("</annotation>\n") 
    annot_file.close()

# %%
# %tensorflow_version 1.x
import tensorflow as tf
import keras
import skimage
print(tf.__version__)
print(keras.__version__) # == 2.2.4
#Tensorflow-gpu version #== 1.12.0
print(skimage.__version__) # == 0.14.2
# Out:
# TensorFlow 1.x selected.
# Using TensorFlow backend.
# 1.15.2
# 2.3.1
# 0.18.3

# %%
#Convert tifs to jpgs 
import gdal
import numpy as np
import gdalnumeric
import os

def tif_to_jpg(tif_file, output_file_name, output_folder):
    #print(tif_file,output_file_name, output_folder)
    ds = gdal.Open(tif_file)
    #geoTrans = srcImage.GetGeoTransform()
    band = ds.GetRasterBand(1)
    width = ds.RasterXSize
    height = ds.RasterYSize

    data = band.ReadAsArray(0, 0, width, height)
    #convert all the bad data
    data[data==-9999.0] = 0
    max_value = np.max(data)
    color_multiplier = 255/(max_value-1)
    #print(color_multiplier)
    data = data*color_multiplier
    #print(data)
    data_int = np.array(data, dtype='int')
    #print(data_int)
    #clip = ds.readasarray(ds)
    data_int = data_int.astype(gdalnumeric.numpy.uint8)
    
    print(os.path.join(output_folder,(output_file_name)))
    gdalnumeric.SaveArray(data_int, os.path.join(output_folder,(output_file_name)), format="JPEG")


tif_images_dir_in = '/content/drive/MyDrive/crane_maryland/slope_images/slope_200-399/'
jpg_images_dir_out = '/content/drive/MyDrive/crane_maryland/slope_images/slope_200-399/jpgs/'

if not (os.path.exists(jpg_images_dir_out)):  
    print("Does not exist.")
    os.mkdir(jpg_images_dir_out)
else:
    print(jpg_images_dir_out, " Exists.")

#tif_to_jpg('/content/drive/MyDrive/crane_maryland/predictions/project_2021_nov_13/slope_tifs/slope_20120131_17SQD2093_utm.tif', '17SQD2093_utm.jpg', '/content/drive/MyDrive/crane_maryland/predictions/project_2021_nov_13/jpgs/')

# find all images
counter = 0
for filename in os.listdir(tif_images_dir_in):
    # extract image id
    image_id = filename[:-4]
    ext = filename[-4:]

    if(ext ==".tif"):
        print(counter, filename)
        img_path = os.path.join(tif_images_dir_in, filename)
        tif_to_jpg(img_path, (filename[:-4]+".jpg"), jpg_images_dir_out)
        
        counter = counter + 1
# Out:
# Does not exist.
# 0 slope_20120219_000018_utm.tif
# /content/drive/MyDrive/crane_maryland/slope_images/slope_200-399/jpgs/slope_20120219_000018_utm.jpg
# 1 slope_20120219_000017_utm.tif
# /content/drive/MyDrive/crane_maryland/slope_images/slope_200-399/jpgs/slope_20120219_000017_utm.jpg
# 2 slope_20120219_000010_utm.tif
# /content/drive/MyDrive/crane_maryland/slope_images/slope_200-399/jpgs/slope_20120219_000010_utm.jpg
# 3 slope_20120219_000009_utm.tif
# /content/drive/MyDrive/crane_maryland/slope_images/slope_200-399/jpgs/slope_20120219_000009_utm.jpg
# 4 slope_20120219_000022_utm.tif
# /content/drive/MyDrive/crane_maryland/slope_images/slope_200-399/jpgs/slope_20120219_000022_utm.jpg
# 5 slope_20120219_000021_utm.tif
# /content/drive/MyDrive/crane_maryland/slope_images/slope_200-399/jpgs/slope_20120219_
utm.tif
# /content/drive/MyDrive/crane_maryland/slope_images/slope_200-399/jpgs/slope_20120313_18STJ5690_utm.jpg
# 179 slope_20120313_18STJ5887_utm.tif
# /content/drive/MyDrive/crane_maryland/slope_images/slope_200-399/jpgs/slope_20120313_18STJ5887_utm.jpg
# 180 slope_20120313_18STJ5695_utm.tif
# /content/drive/MyDrive/crane_maryland/slope_images/slope_200-399/jpgs/slope_20120313_18STJ5695_utm.jpg
# 181 slope_20120313_18STJ5693_utm.tif
# /content/drive/MyDrive/crane_maryland/slope_images/slope_200-399/jpgs/slope_20120313_18STJ5693_utm.jpg
# 182 slope_20120313_18STJ5890_utm.tif
# /content/drive/MyDrive/crane_maryland/slope_images/slope_200-399/jpgs/slope_20120313_18STJ5890_utm.jpg
# 183 slope_20120313_18STJ5889_utm.tif
# /content/drive/MyDrive/crane_maryland/slope_images/slope_200-399/jpgs/slope_20120313_18STJ5889_utm.jpg
# 184 slope_20120313_18STJ5892_utm.tif
# /content/drive/MyDrive/crane_maryland/slope_images/slope_200-399/jpgs/slope_20120313_18STJ5892_utm.jpg
# 185 slope_20120313_18STJ5895_utm.tif
# /content/drive/MyDrive/crane_maryland/slope_images/slope_200-399/jpgs/slope_20120313_18STJ5895_utm.jpg
# 186 slope_20120313_18STJ5893_utm.tif
# /content/drive/MyDrive/crane_maryland/slope_images/slope_200-399/jpgs/slope_20120313_18STJ5893_utm.jpg
# 187 slope_20120313_18STJ5987_utm.tif
# /content/drive/MyDrive/crane_maryland/slope_images/slope_200-399/jpgs/slope_20120313_18STJ5987_utm.jpg
# 188 slope_20120313_18STJ5896_utm.tif
# /content/drive/MyDrive/crane_maryland/slope_images/slope_200-399/jpgs/slope_20120313_18STJ5896_utm.jpg
# 189 slope_20120313_18STJ5990_utm.tif
# /content/drive/MyDrive/crane_maryland/slope_images/slope_200-399/jpgs/slope_20120313_18STJ5990_utm.jpg
# 190 slope_20120313_18STJ5989_utm.tif
# /content/drive/MyDrive/crane_maryland/slope_images/slope_200-399/jpgs/slope_20120313_18STJ5989_utm.jpg
# 191 slope_20120313_18STJ5992_utm.tif
# /content/drive/MyDrive/crane_maryland/slope_images/slope_200-399/jpgs/slope_20120313_18STJ5992_utm.jpg
# 192 slope_20120313_18STJ5995_utm.tif
# /content/drive/MyDrive/crane_maryland/slope_images/slope_200-399/jpgs/slope_20120313_18STJ5995_utm.jpg
# 193 slope_20120313_18STJ5993_utm.tif
# /content/drive/MyDrive/crane_maryland/slope_images/slope_200-399/jpgs/slope_20120313_18STJ5993_utm.jpg
# 194 slope_20120313_18STJ5998_utm.tif
# /content/drive/MyDrive/crane_maryland/slope_images/slope_200-399/jpgs/slope_20120313_18STJ5998_utm.jpg
# 195 slope_20120313_18STJ5996_utm.tif
# /content/drive/MyDrive/crane_maryland/slope_images/slope_200-399/jpgs/slope_20120313_18STJ5996_utm.jpg

# %% [markdown]
# # Quality Assurance: Confirm we have 200 slope tifs and 200 DEM slope jpgs with matching file names.

# %%
# Dictionary of slope_tifs
slope_tifs_fp = '/content/drive/MyDrive/crane_maryland/slope_images/slope_200-399/'
slope_jpgs_fp = '/content/drive/MyDrive/crane_maryland/slope_images/slope_200-399/jpgs/'

slope_tifs_dict = {}
for file_name in os.listdir(slope_tifs_fp):
    origin_file_path = os.path.join(slope_tifs_fp,file_name)
    #print(origin_file_path)
    if(os.path.isfile(origin_file_path)):  
        if(origin_file_path[-4:]==".tif"):
            # be careful comparing a partial filename
            slope_tifs_dict[file_name[:-4]]=file_name


# Dictionary of tifs
slope_jpgs_dict = {}
for file_name in os.listdir(slope_jpgs_fp):
    origin_file_path = os.path.join(slope_jpgs_fp,file_name)
    #print(origin_file_path)
    if(os.path.isfile(origin_file_path)):  
        if(origin_file_path[-4:]==".jpg"):
            # be careful comparing a partial filename
            slope_jpgs_dict[file_name[:-4]]=file_name
#print(tifs_dict)

print("There are: ",len(slope_tifs_dict)," tif files in ", slope_tifs_fp)
for dict_key in slope_tifs_dict:
    if not dict_key in slope_jpgs_dict:
        print(dict_key, " (laz) is not in tifs directory.")

print("There are: ",len(slope_jpgs_dict)," jpg files in ", slope_jpgs_fp)
for dict_key in slope_jpgs_dict:
    if not dict_key in slope_tifs_dict:
        print(dict_key, " (tif) is not in jpgs directory.")

prediction_folder_fp = '/content/drive/MyDrive/crane_maryland/predictions/project_2021_nov_14/cfg20200826T2315/unknown/'

xmls_dict = {}
for file_name in os.listdir(prediction_folder_fp):
    origin_file_path = os.path.join(prediction_folder_fp,file_name)
    #print(origin_file_path)
    if(os.path.isfile(origin_file_path)):  
        if(origin_file_path[-4:]==".xml"):
            # be careful comparing a partial filename
            xmls_dict[file_name[:-4]]=file_name

print("There are: ",len(xmls_dict)," xml files in ", prediction_folder_fp)
for dict_key in xmls_dict:
    if not dict_key in slope_jpgs_dict:
        print(dict_key, " (xml) is not in jpgs directory.")

#print("There are: ",len(slope_jpgs_dict)," jpg files in ", slope_jpgs_fp)
for dict_key in slope_jpgs_dict:
    if not dict_key in xmls_dict:
        print(dict_key, " (jpg) is not in xmls directory.")
# Out:
# There are:  200  tif files in  /content/drive/MyDrive/crane_maryland/slope_images/slope_200-399/
# slope_20120313_18STJ5999_utm  (laz) is not in tifs directory.
# slope_20120313_18STK5801_utm  (laz) is not in tifs directory.
# slope_20120313_18STK5601_utm  (laz) is not in tifs directory.
# slope_20120313_18STK5901_utm  (laz) is not in tifs directory.
# There are:  196  jpg files in  /content/drive/MyDrive/crane_maryland/slope_images/slope_200-399/jpgs/
# There are:  200  xml files in  /content/drive/MyDrive/crane_maryland/predictions/project_2021_nov
# slope_20120219_000051_utm  (jpg) is not in xmls directory.
# slope_20120219_000063_utm  (jpg) is not in xmls directory.
# slope_20120219_000080_utm  (jpg) is not in xmls directory.
# slope_20120219_000100_utm  (jpg) is not in xmls directory.
# slope_20120219_000081_utm  (jpg) is not in xmls directory.
# slope_20120219_000101_utm  (jpg) is not in xmls directory.
# slope_20120220_000119_utm  (jpg) is not in xmls directory.
# slope_20120220_000099_utm  (jpg) is not in xmls directory.
# slope_20120220_000120_utm  (jpg) is not in xmls directory.
# slope_20120220_000174_utm  (jpg) is not in xmls directory.
# slope_20120220_000143_utm  (jpg) is not in xmls directory.
# slope_20120220_000208_utm  (jpg) is not in xmls directory.
# slope_20120220_000207_utm  (jpg) is not in xmls directory.
# slope_20120220_000244_utm  (jpg) is not in xmls directory.
# slope_20120220_000243_utm  (jpg) is not in xmls directory.
# slope_20120129_17SPD9981_utm  (jpg) is not in xmls directory.
# slope_20120129_17SPD9983_utm  (jpg) is not in xmls directory.
# slope_20120129_17SPE9701_utm  (jpg) is not in xmls directory.
# slope_20120129_17SQD0081_utm  (jpg) is not in xmls directory.
# slope_20120129_17SQD0083_utm  (jpg) is not in xmls directory.
# slope_20120129_17SQD0281_utm  (jpg) is not in xmls directory.
# slope_20120129_17SQD0283_utm  (jpg) is not in xmls directory.
# slope_20120129_17SQD0380_utm  (jpg) is not in xmls directory.
# slope_20120129_17SQD0381_utm  (jpg) is not in xmls directory.
# slope_20120129_17SQD0383_utm  (jpg) is not in xmls directory.
# slope_20120129_17SQD0384_utm  (jpg) is not in xmls directory.
# slope_20120129_17SQD0386_utm  (jpg) is not in xmls directory.
# slope_20120129_17SQD0387_utm  (jpg) is not in xmls directory.
# slope_20120129_17SQD0580_utm  (jpg) is not in xmls directory.
# slope_20120129_17SQD0581_utm  (jpg) is not in xmls directory.
# slope_20120129_17SQD0583_utm  (jpg) is not in xmls directory.
# slope_20120129_17SQD0584_utm  (jpg) is not in xmls directory.
# slope_20120129_17SQD0586_utm  (jpg) is not in xmls directory.
# slope_20120129_17SQD0587_utm  (jpg) is not in xmls directory.
# slope_20120129_17SQD0589_utm  (jpg) is not in xmls directory.
# slope_20120129_17SQD0681_utm  (jpg) is not in xmls directory.
# slope_20120129_17SQD0683_utm  (jpg) is not in xmls directory.
# slope_20120129_17SQD0687_utm  (jpg) is not in xmls directory.
# slope_20120129_17SQD0689_utm  (jpg) is not in xmls directory.
# slope_20120129_17SQD0690_utm  (jpg) is not in xmls directory.
# slope_20120129_17SQD0881_utm  (jpg) is not in xmls directory.
# slope_20120129_17SQD0883_utm  (jpg) is not in xmls directory.
# slope_20120129_17SQD0889_utm  (jpg) is not in xmls directory.
# slope_20120129_17SQD0890_utm  (jpg) is not in xmls directory.
# slope_20120129_17SQD0983_utm  (jpg) is not in xmls directory.
# slope_20120129_17SQD0984_utm  (jpg) is not in xmls directory.
# slope_20120129_17SQD0986_utm  (jpg) is not in xmls directory.
# slope_20120129_17SQD0987_utm  (jpg) is not in xmls directory.
# slope_20120129_17SQD0989_utm  (jpg) is not in xmls directory.
# slope_20120129_17SQD1183_utm  (jpg) is not in xmls directory.
# slope_20120129_17SQD1184_utm  (jpg) is not in xmls directory.
# slope_20120129_17SQD1186_utm  (jpg) is not in xmls directory.
# slope_20120129_17SQD1187_utm  (jpg) is not in xmls directory.
# slope_20120129_17SQD1189_utm  (jpg) is not in xmls directory.
# slope_20120129_17SQD1190_utm  (jpg) is not in xmls directory.
# slope_20120129_17SQD1283_utm  (jpg) is not in xmls directory.
# slope_20120129_17SQD1284_utm  (jpg) is not in xmls directory.
# slope_20120129_17SQD1286_utm  (jpg) is not in xmls directory.
# slope_20120129_17SQD1289_utm  (jpg) is not in xmls directory.
# slope_20120129_17SQD1290_utm  (jpg) is not in xmls directory.
# slope_20120130_001119_utm  (jpg) is not in xmls directory.
# slope_20120130_001135_utm  (jpg) is not in xmls directory.
# slope_20120130_001136_utm  (jpg) is not in xmls directory.
# slope_20120130_001137_utm  (jpg) is not in xmls directory.
# slope_20120130_001144_utm  (jpg) is not in xmls directory.
# slope_20120130_001145_utm  (jpg) is not in xmls directory.
# slope_20120130_001146_utm  (jpg) is not in xmls directory.
# slope_20120130_001151_utm  (jpg) is not in xmls directory.
# slope_20120130_001152_utm  (jpg) is not in xmls directory.
# slope_20120130_001153_utm  (jpg) is not in xmls directory.
# slope_20120130_17SPD9980_utm  (jpg) is not in xmls directory.
# slope_20120130_17SQD0080_utm  (jpg) is not in xmls directory.
# slope_20120130_17SQD0280_utm  (jpg) is not in xmls directory.
# slope_20120130_17SQD0678_utm  (jpg) is not in xmls directory.
# slope_20120130_17SQD0680_utm  (jpg) is not in xmls directory.
# slope_20120130_17SQD0878_utm  (jpg) is not in xmls directory.
# slope_20120130_17SQD0880_utm  (jpg) is not in xmls directory.
# slope_20120130_17SQD0980_utm  (jpg) is not in xmls directory.
# slope_20120130_17SQD0981_utm  (jpg) is not in xmls directory.
# slope_20120130_17SQD1178_utm  (jpg) is not in xmls directory.
# slope_20120130_17SQD1180_utm  (jpg) is not in xmls directory.
# slope_20120130_17SQD1181_utm  (jpg) is not in xmls directory.
# slope_20120130_17SQD1481_utm  (jpg) is not in xmls directory.
# slope_20120130_17SQD1483_utm  (jpg) is not in xmls directory.
# slope_20120130_17SQD1578_utm  (jpg) is not in xmls directory.
# slope_20120130_17SQD1580_utm  (jpg) is not in xmls directory.
# slope_20120130_17SQD1783_utm  (jpg) is not in xmls directory.
# slope_20120130_17SQD1880_utm  (jpg) is not in xmls directory.
# slope_20120130_17SQD1881_utm  (jpg) is not in xmls directory.
# slope_20120130_17SQD1883_utm  (jpg) is not in xmls directory.
# slope_20120131_000779_utm  (jpg) is not in xmls directory.
# slope_20120131_000780_utm  (jpg) is not in xmls directory.
# slope_20120131_000822_utm  (jpg) is not in xmls directory.
# slope_20120131_000823_utm  (jpg) is not in xmls directory.
# slope_20120131_000824_utm  (jpg) is not in xmls directory.
# slope_20120131_000861_utm  (jpg) is not in xmls directory.
# slope_20120131_000896_utm  (jpg) is not in xmls directory.
# slope_20120131_000931_utm  (jpg) is not in xmls directory.
# slope_20120131_000967_utm  (jpg) is not in xmls directory.
# slope_20120131_000968_utm  (jpg) is not in xmls directory.
# slope_20120131_001004_utm  (jpg) is not in xmls directory.
# slope_20120131_001040_utm  (jpg) is not in xmls directory.
# slope_20120131_001041_utm  (jpg) is not in xmls directory.
# slope_20120131_001070_utm  (jpg) is not in xmls directory.
# slope_20120131_001071_utm  (jpg) is not in xmls directory.
# slope_20120131_001093_utm  (jpg) is not in xmls directory.
# slope_20120131_001095_utm  (jpg) is not in xmls directory.
# slope_20120131_001096_utm  (jpg) is not in xmls directory.
# slope_20120131_001113_utm  (jpg) is not in xmls directory.
# slope_20120131_001114_utm  (jpg) is not in xmls directory.
# slope_20120131_001115_utm  (jpg) is not in xmls directory.
# slope_20120131_001116_utm  (jpg) is not in xmls directory.
# slope_20120131_001117_utm  (jpg) is not in xmls directory.
# slope_20120131_001130_utm  (jpg) is not in xmls directory.
# slope_20120131_001131_utm  (jpg) is not in xmls directory.
# slope_20120131_001132_utm  (jpg) is not in xmls directory.
# slope_20120131_001133_utm  (jpg) is not in xmls directory.
# slope_20120131_001142_utm  (jpg) is not in xmls directory.
# slope_20120131_001143_utm  (jpg) is not in xmls directory.
# slope_20120131_001149_utm  (jpg) is not in xmls directory.
# slope_20120131_001150_utm  (jpg) is not in xmls directory.
# slope_20120131_17SPD9984_utm  (jpg) is not in xmls directory.
# slope_20120131_17SPD9986_utm  (jpg) is not in xmls directory.
# slope_20120131_17SPD9987_utm  (jpg) is not in xmls directory.
# slope_20120131_17SQD0089_utm  (jpg) is not in xmls directory.
# slope_20120131_17SQD0090_utm  (jpg) is not in xmls directory.
# slope_20120131_17SQD0293_utm  (jpg) is not in xmls directory.
# slope_20120131_17SQD0595_utm  (jpg) is not in xmls directory.
# slope_20120203_000734_utm  (jpg) is not in xmls directory.
# slope_20120203_000735_utm  (jpg) is not in xmls directory.
# slope_20120203_000778_utm  (jpg) is not in xmls directory.
# slope_20120218_000003_utm  (jpg) is not in xmls directory.
# slope_20120218_000011_utm  (jpg) is not in xmls directory.
# slope_20120218_000012_utm  (jpg) is not in xmls directory.
# slope_20120219_000001_utm  (jpg) is not in xmls directory.
# slope_20120219_000002_utm  (jpg) is not in xmls directory.
# slope_20120219_000005_utm  (jpg) is not in xmls directory.
# slope_20120219_000006_utm  (jpg) is not in xmls directory.
# slope_20120219_000007_utm  (jpg) is not in xmls directory.
# slope_20120219_000008_utm  (jpg) is not in xmls directory.
# slope_20120220_000281_utm  (jpg) is not in xmls directory.
# slope_20120220_000322_utm  (jpg) is not in xmls directory.
# slope_20120220_000282_utm  (jpg) is not in xmls directory.
# slope_20120222_000364_utm  (jpg) is not in xmls directory.
# slope_20120220_000323_utm  (jpg) is not in xmls directory.
# slope_20120222_000409_utm  (jpg) is not in xmls directory.
# slope_20120222_000365_utm  (jpg) is not in xmls directory.
# slope_20120226_000456_utm  (jpg) is not in xmls directory.
# slope_20120226_000455_utm  (jpg) is not in xmls directory.
# slope_20120226_000596_utm  (jpg) is not in xmls directory.
# slope_20120226_000549_utm  (jpg) is not in xmls directory.
# slope_20120226_000502_utm  (jpg) is not in xmls directory.
# slope_20120226_000689_utm  (jpg) is not in xmls directory.
# slope_20120226_000643_utm  (jpg) is not in xmls directory.
# slope_20120311_18STJ5680_utm  (jpg) is not in xmls directory.
# slope_20120226_000690_utm  (jpg) is not in xmls directory.
# slope_20120312_18STJ5686_utm  (jpg) is not in xmls directory.
# slope_20120311_18STJ5974_utm  (jpg) is not in xmls directory.
# slope_20120311_18STJ5972_utm  (jpg) is not in xmls directory.
# slope_20120312_18STJ5884_utm  (jpg) is not in xmls directory.
# slope_20120312_18STJ5883_utm  (jpg) is not in xmls directory.
# slope_20120313_18STJ5689_utm  (jpg) is not in xmls directory.
# slope_20120313_18STJ5687_utm  (jpg) is not in xmls directory.
# slope_20120313_18STJ5692_utm  (jpg) is not in xmls directory.
# slope_20120313_18STJ5690_utm  (jpg) is not in xmls directory.
# slope_20120313_18STJ5887_utm  (jpg) is not in xmls directory.
# slope_20120313_18STJ5695_utm  (jpg) is not in xmls directory.
# slope_20120313_18STJ5693_utm  (jpg) is not in xmls directory.
# slope_20120313_18STJ5890_utm  (jpg) is not in xmls directory.
# slope_20120313_18STJ5889_utm  (jpg) is not in xmls directory.
# slope_20120313_18STJ5892_utm  (jpg) is not in xmls directory.
# slope_20120313_18STJ5895_utm  (jpg) is not in xmls directory.
# slope_20120313_18STJ5893_utm  (jpg) is not in xmls directory.
# slope_20120313_18STJ5987_utm  (jpg) is not in xmls directory.
# slope_20120313_18STJ5896_utm  (jpg) is not in xmls directory.
# slope_20120313_18STJ5990_utm  (jpg) is not in xmls directory.
# slope_20120313_18STJ5989_utm  (jpg) is not in xmls directory.
# slope_20120313_18STJ5992_utm  (jpg) is not in xmls directory.
# slope_20120313_18STJ5995_utm  (jpg) is not in xmls directory.
# slope_20120313_18STJ5993_utm  (jpg) is not in xmls directory.
# slope_20120313_18STJ5998_utm  (jpg) is not in xmls directory.
# slope_20120313_18STJ5996_utm  (jpg) is not in xmls directory.

# %%
# Predict it for all the images
# Run Predict Config and Write Annot before running this cell.
cfg_name='cfg20200826T2315'
model_epoch='0016'
object_type = "charcoal_hearth_hill"

print("cfg_name:",cfg_name)

#For all of the jpegs, run prediction

#images_dir
# Run on all images - produce results for analysis.
# images_dir = '/content/drive/MyDrive/crane_maryland/tif/tif_tiles/jpgs'

# 2021 Nov 13
#images_dir = '/content/drive/MyDrive/crane_maryland/predictions/project_2021_nov_13/jpgs/'

images_dir = '/content/drive/MyDrive/crane_maryland/slope_images/slope_0-199/jpgs/'

import os
from os import listdir
import skimage
import cv2
from xml.etree import ElementTree
from numpy import zeros
from numpy import asarray
from mrcnn.utils import Dataset
from mrcnn.visualize import display_instances
from mrcnn.utils import extract_bboxes
from mrcnn.config import Config
import mrcnn.model as modellib

# define the prediction configuration
class PredictionConfig(Config):
	# define the name of the configuration
	NAME = object_type+"_cfg" 
	# number of classes (background + class (charcoal hearth))
	NUM_CLASSES = 1 + 1
	# simplify GPU config
	GPU_COUNT = 1
	IMAGES_PER_GPU = 1

# create config
cfg = PredictionConfig()
# define the model

model = modellib.MaskRCNN(mode='inference', model_dir='/content/drive/MyDrive/MaskCNNhearths/code_and_working_data/charcoal_hearth_hill/model/', config=cfg)
print("Model loaded.")
# load model weights
model_path = '/content/drive/MyDrive/MaskCNNhearths/code_and_working_data/charcoal_hearth_hill/model/charcoal_hearth_hill_cfg20200826T2315/mask_rcnn_charcoal_hearth_hill_cfg_0016.h5'
#model_path = '/home/student/charcoal_hearth_hill/model/'+object_type+'_'+cfg_name+'/mask_rcnn_'+object_type+'_cfg_'+model_epoch+'.h5'
model.load_weights(model_path, by_name=True)

image_prediction_folder = '/content/drive/MyDrive/crane_maryland/predictions/project_2021_nov_14/'+cfg_name+'/'

image_for_prediction_folder = images_dir

if not os.path.exists(image_prediction_folder):
    os.mkdir(image_prediction_folder)
image_prediction_folder = image_prediction_folder+'/unknown/'
if not os.path.exists(image_prediction_folder):
    os.mkdir(image_prediction_folder)
    
    
#Store the results in XML    
class_names = [object_type,object_type,]


# find all images
file_counter = 0
for filename in listdir(images_dir):
    # extract image id
    image_id = filename[:-4]
    ext = filename[-4:]
    if(ext ==".jpg"):
        print(file_counter)  
        img_path = os.path.join(images_dir, filename)
        #ann_path = annotations_dir + image_id + '.xml'
        #print(image_id,img_path,ann_path)
        print(image_id,img_path)
    
        image = cv2.imread(img_path)
        #image = skimage.io.imread(os.path.join(image_for_prediction_folder, test_file_names[cn]))
        #print("shape:", image.shape)
        # Run detection

        results = model.detect([image], verbose=1)
        # Visualize results
        r = results[0]
        #print(r['rois'], class_names, r['scores'])
        #print(r['rois'][1],r['rois'][1][0],r['rois'][1][1],r['rois'][1][2],r['rois'][1][3])
        #image2= display_instances(image, r['rois'], r['masks'], r['class_ids'], 
        #class_names, r['scores'])
        obj_f_num = image_id
        refPts = []
    
        for rcn in range(0,len(r['rois'])):
            refPt = []
            refPtM = []
            refPtM.append(r['rois'][rcn][1])
            refPtM.append(r['rois'][rcn][0])
            refPt.append(refPtM)
            refPtM = []
            refPtM.append(r['rois'][rcn][3])
            refPtM.append(r['rois'][rcn][2])
            refPt.append(refPtM)
            refPts.append(refPt)
            #print(refPts)
        write_annot(class_names[0], image_prediction_folder, obj_f_num, filename, image_for_prediction_folder,image.shape[1],image.shape[0],image.shape[2], refPts,r['scores'])
        file_counter = file_counter + 1
print("The results are in: "+image_prediction_folder)

# %%
        image = cv2.imread('/content/drive/MyDrive/crane_maryland/predictions/project_2021_nov_13/slope_tifs/slope_20120203_17SQD1896_utm.tif')
        #image = skimage.io.imread(os.path.join(image_for_prediction_folder, test_file_names[cn]))
        #print("shape:", image.shape)
        # Run detection
        print(image)

        results = model.detect([image], verbose=1)

# %%
import os
from os import listdir
import cv2
import skimage
from xml.etree import ElementTree
from numpy import zeros
from numpy import asarray
from google.colab.patches import cv2_imshow
from matplotlib import pyplot
from matplotlib.pyplot import figure

#coordinate = "0106"
#training_image = '/content/drive/MyDrive/crane_ane/data/images/jpgs/401'+coordinate +'.jpg'
#prediction_annot_file_path = '/content/drive/MyDrive/MaskCNNhearths/code_and_working_data/charcoal_hearth_hill/predictions/cfg20200826T2315/unknown/401'+coordinate +'.xml'

prediction_image_folder = '/content/drive/MyDrive/crane_maryland/slope_images/slope_0-199/jpgs/'
prediction_annot_folder = '/content/drive/MyDrive/crane_maryland/predictions/project_2021_nov_14/cfg20200826T2315/unknown/'

training_annot_file_path = ""

font = cv2.FONT_HERSHEY_SIMPLEX 
font_scale = 1
font_color = (0, 200, 0) 
font_thickness = 2

file_counter = 0

for prediction_image in listdir(prediction_image_folder):
    print(file_counter, prediction_image)
    if(file_counter>=20 and file_counter<60):
        annotation_file = prediction_image[:-4]+".xml"
        image = cv2.imread(os.path.join(prediction_image_folder,prediction_image))
        print(image.shape)
        prediction_annot_file_path = os.path.join(prediction_annot_folder,annotation_file)

        overlay = image.copy()
        output = image.copy()
        #cv2_imshow(output)    
        font_color = (255, 0, 255)
        font_scale = .6
        font_thickness = 1

        print(prediction_annot_file_path)
        if(os.path.exists(prediction_annot_file_path)):
            tree_train = ElementTree.parse(prediction_annot_file_path)
            root_train = tree_train.getroot()
            for obj in root_train.findall('./object'):
                box = obj.find('bndbox')
                xmin = int(box.find('xmin').text)
                ymin = int(box.find('ymin').text)
                xmax = int(box.find('xmax').text)
                ymax = int(box.find('ymax').text)
                box_num = str(obj.find('number').text)
                score = float(obj.find('score').text)
                if(ymin>ymax):
                    ytemp = ymin
                    ymin = ymax
                    ymax=ytemp
                if(xmin>xmax):
                    xtemp = xmin
                    xmin = xmax
                    xmax=xtemp            
                coors = [xmin, ymin, xmax, ymax]
                crop_output = output[ymin:ymax, xmin:xmax]
        
                cv2.rectangle(output, (xmin, ymin), (xmax, ymax),(255, 0, 255), 2)
                cv2.putText(output, f'{score:.3f}' , (xmin+0, ymin-17), font, font_scale, font_color, font_thickness, cv2.LINE_AA)
            print(root_train.findall('./object'))
            objs = root_train.findall('./object')
            if(len(objs)>0):
                cv2_imshow(output)
        else:
            print("No prediction annotation file for this image.  This is likely ok.")
    file_counter = file_counter +1




#crop_output = output[ymin:ymax, xmin:xmax]
#resized = cv2.resize(output, (64, 30))
# Out:
# Output hidden; open in https://colab.research.google.com to view.
