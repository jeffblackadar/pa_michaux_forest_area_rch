# %% [markdown]
# # Convert Laz to DEM using CloudCompare
#
# # Required software
#
# + CloudCompare
# + QGIS
# + GoogleColab
#
# ## Process flow
#
# https://jeffblackadar.github.io/maryland_rch/maryland_rch-lidar.html
#
# ## File work areas
#
# There are two file works areas
# + (local drive) local PC:
# ```
# E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected
# ```
# + (Google Drive) Google Drive:
#
# laz files
# ```
# /content/drive/MyDrive/crane_pennsylvania/laz/pa_forest_district_01_utm
# ```
#
# programs:
# ```
# /content/drive/MyDrive/crane_pennsylvania/pa_michaux_forest_area_rch
# ```
#
# ### Download files from Google Drive to local drive
#
# There is a constraint that only a 2gb zip file can be downloaded at one time. The .laz files are large so they have been batched into units of 50.
# Download each batch.
#
# ### Local processing
#
# The local PC has CloudCompare and QGIS installed, these are not available on Google Colab so it's necessary to moved files from Google Drive and process them on a PC and then move them back. Manual tasks but I could not find a better means to process these files using this collection of software.
#
# On the local PC laz files will be converted to DEM using CloudCompare. CloudCompare is not installed on Google Colab so it's used on the local PC.
#
# 4 batches of 50 laz files (ex: 0-49, 50-99, 100-149, 150-199) will be downloaed into a folder that can contain 200 files (ex: laz_utm_0-199).
#
# Steps:
#
# #### 1. Create folders to hold downladed files. Example:
# ```
# E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597.
# ```
#
# This can be done by running the first cell of 1_1_Pennsylvania_forest_district_01_download_laz_tiles_use_CloudCompare_to_convert_to_DEM (below)

# %%
# Cell 1. Create working directories
# Run this only once
# set up working directories to hold downloaded files

#easier to do manually for this group of 598
"""
import os
input_laz_utm_fp_base = "E:\\a_new_orgs\\carleton\\pennsylvania_michaux\\lidar_files\\reprojected\\"

chunk_amount = 50
total_files = 599

for count in range(0, total_files , 200):

    new_dir_file_path = os.path.join(input_laz_utm_fp_base, ("laz_utm_"+str(count)+"-"+str(count+chunk_amount-1)))
    print(new_dir_file_path)
    if not (os.path.exists(new_dir_file_path)):  
        print("Does not exist.")
        os.mkdir(new_dir_file_path)
    else:
        print("Exists.")
        
        
input_slope_fp_base = "E:\\a_new_orgs\\carleton\\pennsylvania_michaux\\lidar_files\\slope\\"
for count in range(0, total_files , 200):

    new_dir_file_path = os.path.join(input_slope_fp_base, ("slope_"+str(count)+"-"+str(count+chunk_amount-1)))
    print(new_dir_file_path)
    if not (os.path.exists(new_dir_file_path)):  
        print("Does not exist.")
        os.mkdir(new_dir_file_path)
    else:
        print("Exists.")
"""

# %% [markdown]
# #### 2. Manually download the files from Google Drive. Enter the folder and select the files. Verify 50 items selected.
# (example):
#
# ```
# /content/drive/MyDrive/crane_pennsylvania/laz/pa_forest_district_01_utm/batch_50/laz_utm_0-49
# ```
#
# ![local_processing_step_2.png](local_processing_step_2.png)
#
# #### 3. Unzip into directory the appropriate directory to hold 600 files
# Extract all
#
# (example) from the zip file of 50 files:
#
# ```
# E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_200-249-20211114T195617Z-001.zip\
# ```
#
# (example) to the folder to hold a group of 600 files:
# ```
# E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597.
# ```
#
# Download and unzip groups of 50 files into each folder to contain ~600 files. Check that the folder has 598 files at the end of each group.
#
# ## Run CloudCompare

# %%
# Cell 2 Run CloudCompare
# E:\Program Files\CloudCompare>cloudcompare -O 
#'E:/a_new_orgs/carleton/pennsylvania_michaux/lidar_files/reprojected/20120323_001415_r_utm.laz' 
#-SET_ACTIVE_SF 6 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1

import subprocess
import time

# example command
# C:\LAStools\bin\las2las -i "E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\20120323_001460.laz" -target_utm 18north -o "E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\20120323_001460_r_utm.laz"

batch_group = "0-597"
input_laz_utm_fp = "E:\\a_new_orgs\\carleton\\pennsylvania_michaux\\lidar_files\\reprojected\\laz_utm_"+batch_group+"\\"

counter = 0
import os
#process .laz files one at a time
for root, dirs, files in os.walk(input_laz_utm_fp, topdown=False):
   for name in files:      
      #print(name)
      name_ext = name[-4:].lower()
      if(name_ext==".laz"):
          laz_in_path = os.path.join(input_laz_utm_fp, name)
          #raster_out_path = os.path.join(output_raster_fp, (name[:-4]+".tif"))
          command = '"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O ' + laz_in_path + " -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z "
          print(str(counter))        
          print("!"+command)
          subprocess.call(command, shell=True)
          # just in case, let the sub process run
          #time.sleep(4)
          counter = counter + 1        
        

"""
Rasterizes the loaded clouds by projecting them inside a regular grid.
Optional settings are:

-VERT_DIR {0/1/2} to specify the projection dimension (0=X / 1=Y / 2=Z) - default is 2 (Z)
-PROJ {MIN/AVG/MAX} to specify how the altitude of each cell is computed (minimum, average or maximum altitude of the projected points). Default is AVG (average)
-SF_PROJ {MIN/AVG/MAX} to specify how the SF value(s) of each cell are computed (minimum, average or maximum altitude of the projected points SF value(s)). Default is AVG (average)
-EMPTY_FILL {MIN_H/MAX_H/CUSTOM_H/INTERP} to specify how empty cells should be filled (MIN_H = min height / MAX_H = max height / CUSTOM_H = custom value - see CUSTOM_HEIGHT option below / INTERP = interpolate). Default behavior is 'leave cells empty'
-CUSTOM_HEIGHT {value} to define the custom height filling value (if the 'CUSTOM_H' strategy is used (see above)
-OUTPUT_CLOUD to output the result as a cloud (this is the default option if no other output format is defined)
-OUTPUT_MESH to output the result as a mesh
-OUTPUT_RASTER_Z to output the result as a geotiff raster (only altitudes, no RGB)
-OUTPUT_RASTER_Z_AND_SF to output the result as a geotiff raster (altitudes + all SFs by default, no RGB)
-OUTPUT_RASTER_RGB to output the result as a geotiff raster (RGB)        
"""
# Out:
# 0
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\15001970pas10_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 1
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\15001980pas10_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 2
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\15001990pas10_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 3
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\15002000pas10_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 4
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\15002010pas10_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 5
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\15002020pas10_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 6
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\15002030pas10_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 7
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\15002040pas10_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 8
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\15002050pas10_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 9
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\15002060pas10_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 10
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\15002070pas10_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 11
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\15002080pas10_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 12
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\15002090pas10_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 13
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\15002100pas10_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 14
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\15002110pas10_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 15
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\15002120pas10_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 16
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\15002130pas10_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 17
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\15002140pas10_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 18
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\15002150pas10_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 19
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\15002160pas10_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 20
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\15002170pas10_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 21
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\15002180pas10_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 22
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\15002190pas11_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 23
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\15002200pas11_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 24
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\15002210pas11_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 25
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\15002220pas11_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 26
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\15002230pas11_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 27
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\15002240pas11_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 28
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\15002250pas11_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 29
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\15002260pas11_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 30
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\15002270pas11_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 31
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\15002280pas11_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 32
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\15002290pas11_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 33
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\15002300pas11_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 34
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\15002310pas11_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 35
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\15002320pas11_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 36
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\15002330pas11_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 37
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\15002340pas11_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 38
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\15002350pas11_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 39
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\15002360pas11_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 40
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\15002370pas11_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 41
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\15002380pas11_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 42
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\15002390pas11_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 43
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\16001970pas10_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 44
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\16001980pas10_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 45
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\16001990pas10_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 46
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\16002000pas10_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 47
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\16002010pas10_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 48
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\16002020pas10_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 49
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\16002030pas10_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 50
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\16002040pas10_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 51
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\16002050pas10_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 52
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\16002060pas10_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 53
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\16002070pas10_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 54
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\16002080pas10_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 55
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\16002090pas10_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 56
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\16002100pas10_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 57
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\16002110pas10_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 58
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\16002120pas10_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 59
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\16002130pas10_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 60
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\16002140pas10_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 61
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\16002150pas10_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 62
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\16002160pas10_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 63
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\16002170pas10_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 64
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\16002180pas10_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 65
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\16002190pas11_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 66
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\16002200pas11_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 67
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\16002210pas11_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 68
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\16002220pas11_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 69
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\16002230pas11_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 70
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\16002240pas11_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 71
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\16002250pas11_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 72
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\16002260pas11_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 73
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\16002270pas11_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 74
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\16002280pas11_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 75
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\16002290pas11_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 76
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\16002300pas11_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 77
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\16002310pas11_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 78
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\16002320pas11_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 79
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\16002330pas11_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 80
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\16002340pas11_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 81
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\16002350pas11_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 82
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\16002360pas11_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 83
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\16002370pas11_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 84
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\16002380pas11_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 85
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\16002390pas11_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 86
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\17001970pas10_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 87
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\17001980pas10_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 88
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\17001990pas10_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 89
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\17002000pas10_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 90
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\17002010pas10_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 91
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\17002020pas10_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 92
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\17002030pas10_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 93
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\17002040pas10_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 94
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\17002050pas10_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 95
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\17002060pas10_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 96
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\17002070pas10_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 97
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\17002080pas10_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 98
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\17002090pas10_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 99
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\17002100pas10_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 100
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\17002110pas10_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 101
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\17002120pas10_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 102
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\17002130pas10_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 103
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\17002140pas10_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 104
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\17002150pas10_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 105
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\17002160pas10_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 106
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\17002170pas10_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 107
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\17002180pas10_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 108
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\17002190pas11_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 109
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\17002200pas11_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 110
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\17002210pas11_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 111
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\17002220pas11_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 112
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\17002230pas11_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 113
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\17002240pas11_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 114
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\17002250pas11_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 115
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\17002260pas11_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 116
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\17002270pas11_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 117
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\17002280pas11_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 118
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\17002290pas11_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 119
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\17002300pas11_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 120
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\17002310pas11_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 121
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\17002320pas11_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 122
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\17002330pas11_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 123
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\17002340pas11_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 124
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\17002350pas11_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 125
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\17002360pas11_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 126
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\17002370pas11_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 127
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\17002380pas11_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 128
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\18001970pas10_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 129
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\18001980pas10_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 130
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\18001990pas10_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 131
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\18002000pas10_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 132
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\18002010pas10_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 133
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\18002020pas10_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 134
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\18002030pas10_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 135
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\18002040pas10_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 136
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\18002050pas10_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 137
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\18002060pas10_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 138
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\18002070pas10_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 139
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\18002080pas10_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 140
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\18002090pas10_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 141
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\18002100pas10_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 142
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\18002110pas10_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 143
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\18002120pas10_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 144
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\18002130pas10_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 145
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\18002140pas10_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 146
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\18002150pas10_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 147
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\18002160pas10_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 148
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\18002170pas10_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 149
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\18002180pas10_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 150
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\18002190pas11_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 151
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\18002200pas11_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 152
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\18002210pas11_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 153
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\18002220pas11_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 154
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\18002230pas11_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 155
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\18002240pas11_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 156
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\18002250pas11_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 157
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\18002260pas11_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 158
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\18002270pas11_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 159
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\18002280pas11_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 160
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\18002290pas11_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 161
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\18002300pas11_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 162
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\18002310pas11_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 163
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\18002320pas11_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 164
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\18002330pas11_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 165
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\18002340pas11_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 166
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\18002350pas11_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 167
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\18002360pas11_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 168
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\18002370pas11_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 169
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\19001970pas10_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 170
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\19001980pas10_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 171
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\19001990pas10_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 172
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\19002000pas10_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 173
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\19002010pas10_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 174
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\19002020pas10_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 175
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\19002030pas10_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 176
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\19002040pas10_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 177
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\19002050pas10_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 178
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\19002060pas10_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 179
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\19002070pas10_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 180
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\19002080pas10_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 181
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\19002090pas10_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 182
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\19002100pas10_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 183
# ...
# 544
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\2000_30002210pas11_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 545
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\2000_30002220pas11_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 546
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\2000_30002230pas11_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 547
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\2000_30002240pas11_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 548
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\2000_30002250pas11_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 549
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\2000_31002080pas10_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 550
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\2000_31002090pas10_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 551
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\2000_31002100pas10_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 552
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\2000_31002110pas10_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 553
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\2000_31002120pas10_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 554
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\2000_31002130pas10_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 555
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\2000_31002140pas10_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 556
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\2000_31002150pas10_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 557
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\2000_31002160pas10_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 558
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\2000_31002170pas10_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 559
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\2000_31002180pas10_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 560
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\2000_31002190pas11_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 561
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\2000_31002200pas11_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 562
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\2000_31002210pas11_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 563
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\2000_31002220pas11_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 564
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\2000_31002230pas11_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 565
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\2000_31002240pas11_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 566
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\2000_32002100pas10_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 567
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\2000_32002110pas10_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 568
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\2000_32002120pas10_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 569
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\2000_32002130pas10_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 570
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\2000_32002140pas10_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 571
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\2000_32002150pas10_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 572
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\2000_32002160pas10_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 573
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\2000_32002170pas10_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 574
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\2000_32002180pas10_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 575
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\2000_32002190pas11_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 576
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\2000_32002200pas11_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 577
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\2000_32002210pas11_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 578
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\2000_32002220pas11_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 579
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\2000_32002230pas11_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 580
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\2000_32002240pas11_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 581
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\2000_33002120pas10_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 582
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\2000_33002130pas10_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 583
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\2000_33002140pas10_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 584
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\2000_33002150pas10_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 585
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\2000_33002160pas10_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 586
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\2000_33002170pas10_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 587
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\2000_33002180pas10_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 588
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\2000_33002190pas11_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 589
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\2000_33002200pas11_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 590
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\2000_33002210pas11_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 591
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\2000_33002220pas11_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 592
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\2000_34002160pas04_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 593
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\2000_34002170pas04_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 594
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\2000_34002180pas04_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 595
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\2000_34002190pas11_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 596
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\2000_34002200pas11_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# 597
# !"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\2000_34002210pas11_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z
# "\nRasterizes the loaded clouds by projecting them inside a regular grid.\nOptional settings are:\n\n-VERT_DIR {0/1/2} to specify the projection dimension (0=X / 1=Y / 2=Z) - default is 2 (Z)\n-PROJ {MIN/AVG/MAX} to specify how the altitude of each cell is computed (minimum, average or maximum altitude of the projected points). Default is AVG (average)\n-SF_PROJ {MIN/AVG/MAX} to specify how the SF value(s) of each cell are computed (minimum, average or maximum altitude of the projected points SF value(s)). Default is AVG (average)\n-EMPTY_FILL {MIN_H/MAX_H/CUSTOM_H/INTERP} to specify how empty cells should be filled (MIN_H = min height / MAX_H = max height / CUSTOM_H = custom value - see CUSTOM_HEIGHT option below / INTERP = interpolate). Default behavior is 'leave cells empty'\n-CUSTOM_HEIGHT {value} to define the custom height filling value (if the 'CUSTOM_H' strategy is used (see above)\n-OUTPUT_CLOUD to output the result as a cloud (this is the default option if no other output format is defined)\n-OUTPUT_MESH to output the result as a mesh\n-OUTPUT_RASTER_Z to output the result as a geotiff raster (only altitudes, no RGB)\n-OUTPUT_RASTER_Z_AND_SF to output the result as a geotiff raster (altitudes + all SFs by default, no RGB)\n-OUTPUT_RASTER_RGB to output the result as a geotiff raster (RGB)        \n"

# %% [markdown]
# # Re-run a skipped command individually

# %%
!"E:\\Program Files\\CloudCompare\\cloudcompare" -SILENT -O E:\\a_new_orgs\\carleton\\pennsylvania_michaux\\lidar_files\\reprojected\\laz_utm_200-399\\20120218_000003_utm.laz -SET_ACTIVE_SF 8 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z

# %% [markdown]
# # Copy/Move tifs
#
# CloudCompare creates the DEM tifs in the same directory as the las files. This program copies them to their own directory. Later, once this process is more repeatable, this will become a move, not a copy, to save disk space.
#
# ## !! Be careful and set the directories correctly.  Mixing batches together is annoying

# %%
# Cell 3 Copy/Move tifs
import os
import shutil
# Divide files into groups of 200 so they can be downloaded and processed in managably sized chunks.
file_counter = 0

batch_group = "0-597"
input_laz_utm_fp = "E:\\a_new_orgs\\carleton\\pennsylvania_michaux\\lidar_files\\reprojected\\laz_utm_"+batch_group+"\\"
dem_tif_fp_dest = os.path.join("E:\\a_new_orgs\\carleton\\pennsylvania_michaux\\lidar_files\\reprojected\\laz_utm_"+batch_group+"\
as11_utm.laz
# E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\2000_32002230pas11_utm_2022-04-08_19h49_27_222.bin
# E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\2000_32002240pas11_utm.laz
# E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\2000_32002240pas11_utm_2022-04-08_19h49_38_730.bin
# E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\2000_33002120pas10_utm.laz
# E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\2000_33002120pas10_utm_2022-04-08_19h49_51_803.bin
# E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\2000_33002130pas10_utm.laz
# E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\2000_33002130pas10_utm_2022-04-08_19h50_04_779.bin
# E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\2000_33002140pas10_utm.laz
# E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\2000_33002140pas10_utm_2022-04-08_19h50_17_164.bin
# E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\2000_33002150pas10_utm.laz
# E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\2000_33002150pas10_utm_2022-04-08_19h50_29_421.bin
# E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\2000_33002160pas10_utm.laz
# E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\2000_33002160pas10_utm_2022-04-08_19h50_42_330.bin
# E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\2000_33002170pas10_utm.laz
# E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\2000_33002170pas10_utm_2022-04-08_19h50_55_026.bin
# E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\2000_33002180pas10_utm.laz
# E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\2000_33002180pas10_utm_2022-04-08_19h51_07_801.bin
# E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\2000_33002190pas11_utm.laz
# E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\2000_33002190pas11_utm_2022-04-08_19h51_21_012.bin
# E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\2000_33002200pas11_utm.laz
# E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\2000_33002200pas11_utm_2022-04-08_19h51_34_989.bin
# E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\2000_33002210pas11_utm.laz
# E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\2000_33002210pas11_utm_2022-04-08_19h51_48_154.bin
# E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\2000_33002220pas11_utm.laz
# E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\2000_33002220pas11_utm_2022-04-08_19h52_00_269.bin
# E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\2000_34002160pas04_utm.laz
# E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\2000_34002160pas04_utm_2022-04-08_19h52_13_789.bin
# E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\2000_34002170pas04_utm.laz
# E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\2000_34002170pas04_utm_2022-04-08_19h52_27_091.bin
# E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\2000_34002180pas04_utm.laz
# E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\2000_34002180pas04_utm_2022-04-08_19h52_40_590.bin
# E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\2000_34002190pas11_utm.laz
# E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\2000_34002190pas11_utm_2022-04-08_19h52_54_584.bin
# E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\2000_34002200pas11_utm.laz
# E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\2000_34002200pas11_utm_2022-04-08_19h53_07_788.bin
# E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\2000_34002210pas11_utm.laz
# E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\2000_34002210pas11_utm_2022-04-08_19h53_20_576.bin
# E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\dem_tifs

# %% [markdown]
# # Quality Assurance 1: Confirm we have 598 lazs and 598 DEM tifs with matching file names.

# %%
# Cell 4 Quality Assurance 1
# Dictionary of lazs
batch_group = "0-597"
expected_number_of_files = 598
input_laz_utm_fp = "E:\\a_new_orgs\\carleton\\pennsylvania_michaux\\lidar_files\\reprojected\\laz_utm_"+batch_group+"\\"
dem_tif_fp_dest = os.path.join("E:\\a_new_orgs\\carleton\\pennsylvania_michaux\\lidar_files\\reprojected\\laz_utm_"+batch_group+"\\dem_tifs\\")

lazs_dict = {}
for file_name in os.listdir(input_laz_utm_fp):
    origin_file_path = os.path.join(input_laz_utm_fp,file_name)
    if(os.path.isfile(origin_file_path)):  
        if(origin_file_path[-4:]==".laz"):
            lazs_dict[file_name[:file_name.find("_utm")+4]]=file_name

# Dictionary of tifs
tifs_dict = {}
for file_name in os.listdir(dem_tif_fp_dest):
    origin_file_path = os.path.join(dem_tif_fp_dest,file_name)
    if(os.path.isfile(origin_file_path)):  
        if(origin_file_path[-4:]==".tif"):
            tifs_dict[file_name[:file_name.find("_utm")+4]]=file_name

counter = 0
print("There are:",len(lazs_dict),"laz files in", input_laz_utm_fp)
print("There are:",len(tifs_dict),"tif files in", dem_tif_fp_dest)
for dict_key in lazs_dict:
    if not dict_key in tifs_dict:
        print(lazs_dict[dict_key], " (laz) is not in tifs directory.")
        print("Let's try to process with a scalar field index of 5. For some Laz files, Classfication is at the index of 5, not 8.")
        laz_in_path = os.path.join(input_laz_utm_fp, lazs_dict[dict_key])
        # The index of the scalar field is 6 this time -SET_ACTIVE_SF 6
        command = '"E:\Program Files\CloudCompare\cloudcompare" -SILENT -O ' + laz_in_path + " -SET_ACTIVE_SF 5 -FILTER_SF 1.1 2.1 -RASTERIZE -GRID_STEP 1 -EMPTY_FILL INTERP -OUTPUT_RASTER_Z "
        print("file",str(counter), "processed.")
        print("!"+command)
        subprocess.call(command, shell=True)
        counter = counter + 1        


for dict_key in tifs_dict:
    if not dict_key in lazs_dict:
        print(tifs_dict[dict_key], "(tif) is not in lazs directory.")
      
if len(lazs_dict)==expected_number_of_files and len(tifs_dict)==expected_number_of_files:
    print("Both directories have",expected_number_of_files,"files. This looks good.")
else:
    print("There is a problem. Check the number of files in each folder.")
# Out:
# There are: 598 laz files in E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\
# There are: 598 tif files in E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\dem_tifs\
# Both directories have 598 files. This looks good.

# %% [markdown]
# # Open QGIS, Run:
# ```
# 1_2_qgis_load_dem_save_as_slope.py
# ```
# This saves a slope file for each DEM tif in the diectory
#
# ```
# 1_3_qgis_save_slope_tif_as_jpg.py
# ```
# This saves a jpg file for each slope tif in the diectory

# %% [markdown]
# # Quality Assurance 2: Confirm we have 598 lazs, 598 DEM tifs, 598 Slope tifs and 598 Slope jpgs with matching file names.

# %%
# Cell 5 Quality Assurance
# Dictionary of lazs

input_laz_utm_fp = "E:\\a_new_orgs\\carleton\\pennsylvania_michaux\\lidar_files\\reprojected\\laz_utm_"+batch_group+"\\"
dem_tif_fp_dest = os.path.join("E:\\a_new_orgs\\carleton\\pennsylvania_michaux\\lidar_files\\reprojected\\laz_utm_"+batch_group+"\\dem_tifs\\")

lazs_dict = {}
for file_name in os.listdir(input_laz_utm_fp):
    origin_file_path = os.path.join(input_laz_utm_fp,file_name)
    if(os.path.isfile(origin_file_path)):  
        if(origin_file_path[-4:]==".laz"):
            lazs_dict[file_name[:file_name.find("_utm")+4]]=file_name

# Dictionary of tifs
tifs_dict = {}
for file_name in os.listdir(dem_tif_fp_dest):
    origin_file_path = os.path.join(dem_tif_fp_dest,file_name)
    if(os.path.isfile(origin_file_path)):  
        if(origin_file_path[-4:]==".tif"):
            tifs_dict[file_name[:file_name.find("_utm")+4]]=file_name

counter = 0
print("There are:",len(lazs_dict),"laz files in", input_laz_utm_fp)
for dict_key in lazs_dict:
    if not dict_key in tifs_dict:
        print(lazs_dict[dict_key], "(laz) is not in tifs directory.")
        print("Go back to cell 4 and re-run the process. All of the lazs need to be converted to DEM tifs before running QGIS to create slope files.")
        print("file",str(counter), "processed.")
        counter = counter + 1        

print("There are:",len(tifs_dict),"tif files in", dem_tif_fp_dest)
for dict_key in tifs_dict:
    if not dict_key in lazs_dict:
        print(tifs_dict[dict_key], "(tif) is not in lazs directory.")        

# Dictionary of slope tifs
slope_tifs_dict = {}
slope_tifs_fp = "E:\\a_new_orgs\\carleton\\pennsylvania_michaux\\lidar_files\\slope\\slope_"+batch_group+"\\"

for file_name in os.listdir(slope_tifs_fp):
    origin_file_path = os.path.join(slope_tifs_fp,file_name)
    #print(origin_file_path)
    if(os.path.isfile(origin_file_path)):
        if(origin_file_path[-4:]==".tif"):
            slope_tifs_dict[file_name[6:-4]]=file_name

print("There are:",len(slope_tifs_dict),"slope files in", slope_tifs_fp)
for dict_key in slope_tifs_dict:
    if not dict_key in tifs_dict:
        print(dict_key, "(slope tif) is not in DEM tifs directory.")
        
# Dictionary of slope jpgs
slope_jpgs_dict = {}
slope_jpgs_fp = "E:\\a_new_orgs\\carleton\\pennsylvania_michaux\\lidar_files\\slope\\slope_"+batch_group+"\\jpgs\\"

for file_name in os.listdir(slope_jpgs_fp ):
    origin_file_path = os.path.join(slope_jpgs_fp ,file_name)
    #print(origin_file_path)
    if(os.path.isfile(origin_file_path)):  
        if(origin_file_path[-4:]==".jpg"):
            slope_jpgs_dict[file_name[6:-4]]=file_name

print("There are:",len(slope_jpgs_dict),"slope jpg files in", slope_jpgs_fp)
for dict_key in slope_jpgs_dict:
    if not dict_key in slope_tifs_dict:
        print(dict_key, "(slope jpg) is not in slope tifs directory.")

if len(lazs_dict)==expected_number_of_files and len(tifs_dict)==expected_number_of_files and len(slope_tifs_dict)==expected_number_of_files and len(slope_jpgs_dict)==expected_number_of_files:
    print("All directories have",expected_number_of_files," files. This looks good.")
else:
    print("There is a problem. Check the number of files in each folder.")
# Out:
# There are: 598 laz files in E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\
# There are: 598 tif files in E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\reprojected\laz_utm_0-597\dem_tifs\
# There are: 598 slope files in E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\slope\slope_0-597\
# There are: 598 slope jpg files in E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\slope\slope_0-597\jpgs\
# All directories have 598  files. This looks good.

# %% [markdown]
# #### Copy JPGs and Tifs to Google Drive
# The jpgs are needed for Mask R-CNN recognition. The Tifs are needed to convert image coordinates back into geographic coordinates.
#
# Copy the jpg files to Google drive so they can be used by Mask R-CNN.
#
# In E:\a_new_orgs\carleton\pennsylvania_michaux\lidar_files\slope
# drag a folder (example: 0-597) to
#
# to My Drive/pennsylvania_michaux/slope_images/
