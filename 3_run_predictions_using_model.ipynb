# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/crane_maryland
# !mkdir /content/drive/MyDrive/crane_maryland/mask-rcnn-repository
# Out:
# /content/drive/MyDrive/crane_maryland
# mkdir: cannot create directory ‘/content/drive/MyDrive/crane_maryland/mask-rcnn-repository’: File exists

# %%
# !mkdir /content/drive/MyDrive/crane_maryland/predictions

# %%
# !mkdir /content/drive/MyDrive/crane_maryland/polys

# %%
# %cd /content/drive/MyDrive/crane_maryland/mask-rcnn-repository
# Out:
# /content/drive/MyDrive/crane_maryland/mask-rcnn-repository

# %%
# !git clone https://github.com/matterport/Mask_RCNN.git
# Out:
# fatal: destination path 'Mask_RCNN' already exists and is not an empty directory.

# %%
#Thanks to https://emadehsan.com/p/object-detection
# %cd /content/drive/MyDrive/crane_maryland/mask-rcnn-repository/Mask_RCNN
# !python setup.py install
# Out:
# /content/drive/MyDrive/crane_maryland/mask-rcnn-repository/Mask_RCNN
# WARNING:root:Fail load requirements file, so using default ones.
# /usr/local/lib/python3.7/dist-packages/setuptools/dist.py:700: UserWarning: Usage of dash-separated 'description-file' will not be supported in future versions. Please use the underscore name 'description_file' instead
#   % (opt, underscore_opt))
# /usr/local/lib/python3.7/dist-packages/setuptools/dist.py:700: UserWarning: Usage of dash-separated 'license-file' will not be supported in future versions. Please use the underscore name 'license_file' instead
#   % (opt, underscore_opt))
# /usr/local/lib/python3.7/dist-packages/setuptools/dist.py:700: UserWarning: Usage of dash-separated 'requirements-file' will not be supported in future versions. Please use the underscore name 'requirements_file' instead
#   % (opt, underscore_opt))
# running install
# running bdist_egg
# running egg_info
# writing mask_rcnn.egg-info/PKG-INFO
# writing dependency_links to mask_rcnn.egg-info/dependency_links.txt
# writing top-level names to mask_rcnn.egg-info/top_level.txt
# reading manifest template 'MANIFEST.in'
# adding license file 'LICENSE'
# writing manifest file 'mask_rcnn.egg-info/SOURCES.txt'
# installing library code to build/bdist.linux-x86_64/egg
# running install_lib
# running build_py
# creating build/bdist.linux-x86_64/egg
# creating build/bdist.linux-x86_64/egg/mrcnn
# copying build/lib/mrcnn/visualize.py -> build/bdist.linux-x86_64/egg/mrcnn
# copying build/lib/mrcnn/parallel_model.py -> build/bdist.linux-x86_64/egg/mrcnn
# copying build/lib/mrcnn/utils.py -> build/bdist.linux-x86_64/egg/mrcnn
# copying build/lib/mrcnn/config.py -> build/bdist.linux-x86_64/egg/mrcnn
# copying build/lib/mrcnn/__init__.py -> build/bdist.linux-x86_64/egg/mrcnn
# copying build/lib/mrcnn/model.py -> build/bdist.linux-x86_64/egg/mrcnn
# byte-compiling build/bdist.linux-x86_64/egg/mrcnn/visualize.py to visualize.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mrcnn/parallel_model.py to parallel_model.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mrcnn/utils.py to utils.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mrcnn/config.py to config.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mrcnn/__init__.py to __init__.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mrcnn/model.py to model.cpython-37.pyc
# creating build/bdist.linux-x86_64/egg/EGG-INFO
# copying mask_rcnn.egg-info/PKG-INFO -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying mask_rcnn.egg-info/SOURCES.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying mask_rcnn.egg-info/dependency_links.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying mask_rcnn.egg-info/top_level.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# zip_safe flag not set; analyzing archive contents...
# creating 'dist/mask_rcnn-2.1-py3.7.egg' and adding 'build/bdist.linux-x86_64/egg' to it
# removing 'build/bdist.linux-x86_64/egg' (and everything under it)
# Processing mask_rcnn-2.1-py3.7.egg
# Copying mask_rcnn-2.1-py3.7.egg to /usr/local/lib/python3.7/dist-packages
# Adding mask-rcnn 2.1 to easy-install.pth file
#
# Installed /usr/local/lib/python3.7/dist-packages/mask_rcnn-2.1-py3.7.egg
# Processing dependencies for mask-rcnn==2.1
# Finished processing dependencies for mask-rcnn==2.1

# %%
# !pip install 'h5py<3.0.0'
# Out:
# Collecting h5py<3.0.0
#   Downloading h5py-2.10.0-cp37-cp37m-manylinux1_x86_64.whl (2.9 MB)
#      |████████████████████████████████| 2.9 MB 10.1 MB/s
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from h5py<3.0.0) (1.15.0)
# Requirement already satisfied: numpy>=1.7 in /usr/local/lib/python3.7/dist-packages (from h5py<3.0.0) (1.19.5)
# Installing collected packages: h5py
#   Attempting uninstall: h5py
#     Found existing installation: h5py 3.1.0
#     Uninstalling h5py-3.1.0:
#       Successfully uninstalled h5py-3.1.0
# Successfully installed h5py-2.10.0

# %%
import os
# Root directory of the project
ROOT_DIR = os.path.abspath("./content/drive/MyDrive/crane_maryland/mask-rcnn-repository/Mask_RCNN")

# Import Mask RCNN
# !sys.path.append(ROOT_DIR)
# Out:
# /bin/bash: -c: line 0: syntax error near unexpected token `ROOT_DIR'
# /bin/bash: -c: line 0: `sys.path.append(ROOT_DIR)'

# %%
# Write Annot
def write_annot(obj_type, obj_annots_dir, obj_f_num, org_f_name, org_f_path,org_f_width,org_f_height,org_f_depth, refPts, scores):
    # With credit to: 
    # https://www.geeksforgeeks.org/reading-writing-text-files-python/
    annot_file_path = obj_annots_dir+obj_f_num+'.xml'
    annot_file = open(annot_file_path,"w") 

    annot_file.write("<annotation>\n") 
    annot_file.write("	<folder>"+obj_type+"</folder>\n") 
    annot_file.write("	<filename>"+org_f_name+"</filename>\n") 
    annot_file.write("	<path>"+org_f_path+"</path>\n") 
    annot_file.write("	<source>\n") 
    annot_file.write("		<database>Muhlenberg_charcoal_hearths</database>\n") 
    annot_file.write("	</source>\n") 
    annot_file.write("	<size>\n") 
    annot_file.write("		<width>"+str(org_f_width)+"</width>\n") 
    annot_file.write("		<height>"+str(org_f_height)+"</height>\n") 
    annot_file.write("		<depth>"+str(org_f_depth)+"</depth>\n") 
    annot_file.write("	</size>\n")
    annot_file.write("	<!-- <object_present>0 = the object is not present in the image. 1 = it is -->\n")
    annot_file.write("	<object_present>0</object_present>\n")    
    for ocn in range(0,len(refPts)):
        refPt = refPts[ocn]
        refPtMin = refPt[0]
        refPtMax = refPt[1]
        annot_file.write("	<object>\n") 
        annot_file.write("		<name>"+obj_type+"</name>\n") 
        annot_file.write("		<number>"+str(ocn)+"</number>\n") 
        annot_file.write("		<score>"+str(scores[ocn])+"</score>\n")
        annot_file.write("		<correct>0</correct>\n")
        annot_file.write("		<bndbox>\n") 
        annot_file.write("			<xmin>"+str(refPtMin[0])+"</xmin>\n") 
        annot_file.write("			<ymin>"+str(refPtMin[1])+"</ymin>\n") 
        annot_file.write("			<xmax>"+str(refPtMax[0])+"</xmax>\n") 
        annot_file.write("			<ymax>"+str(refPtMax[1])+"</ymax>\n") 
        annot_file.write("		</bndbox>\n") 
        annot_file.write("	</object>\n") 
    annot_file.write("</annotation>\n") 
    annot_file.close()

# %%
# %tensorflow_version 1.x
import tensorflow as tf
import keras
import skimage
print(tf.__version__)
print(keras.__version__) # == 2.2.4
#Tensorflow-gpu version #== 1.12.0
print(skimage.__version__) # == 0.14.2
# Out:
# TensorFlow 1.x selected.
# 1.15.2
# 2.3.1
# 0.16.2
# Using TensorFlow backend.

# %%
#Convert tifs to jpgs 
import gdal
import numpy as np
import gdalnumeric
def tif_to_jpg(tif_file, output_file_name, output_folder):
    #print(tif_file,output_file_name, output_folder)
    ds = gdal.Open(tif_file)
    #geoTrans = srcImage.GetGeoTransform()
    band = ds.GetRasterBand(1)
    width = ds.RasterXSize
    height = ds.RasterYSize

    data = band.ReadAsArray(0, 0, width, height)
    #convert all the bad data
    data[data==-9999.0] = 0
    max_value = np.max(data)
    color_multiplier = 255/(max_value-1)
    #print(color_multiplier)
    data = data*color_multiplier
    #print(data)
    data_int = np.array(data, dtype='int')
    #print(data_int)
    #clip = ds.readasarray(ds)
    data_int = data_int.astype(gdalnumeric.numpy.uint8)
    
    print(os.path.join(output_folder,(output_file_name)))
    gdalnumeric.SaveArray(data_int, os.path.join(output_folder,(output_file_name)), format="JPEG")

# 2021 Nov 13
tif_images_dir_in = '/content/drive/MyDrive/crane_maryland/predictions/project_2021_nov_13/slope_tifs/'
jpg_images_dir_out = '/content/drive/MyDrive/crane_maryland/predictions/project_2021_nov_13/jpgs/'

#tif_to_jpg('/content/drive/MyDrive/crane_maryland/predictions/project_2021_nov_13/slope_tifs/slope_20120131_17SQD2093_utm.tif', '17SQD2093_utm.jpg', '/content/drive/MyDrive/crane_maryland/predictions/project_2021_nov_13/jpgs/')

# find all images
for filename in listdir(tif_images_dir_in):
    # extract image id
    image_id = filename[:-4]
    ext = filename[-4:]

    if(ext ==".tif"):
        img_path = os.path.join(tif_images_dir_in, filename)
        tif_to_jpg(img_path, (filename[:-4]+".jpg"), jpg_images_dir_out)
# Out:
# /content/drive/MyDrive/crane_maryland/predictions/project_2021_nov_13/jpgs/slope_20120203_17SQD1896_utm.jpg
# /content/drive/MyDrive/crane_maryland/predictions/project_2021_nov_13/jpgs/slope_20120203_17SQD1799_utm.jpg
# /content/drive/MyDrive/crane_maryland/predictions/project_2021_nov_13/jpgs/slope_20120203_17SQD1596_utm.jpg
# /content/drive/MyDrive/crane_maryland/predictions/project_2021_nov_13/jpgs/slope_20120203_17SQD1899_utm.jpg
# /content/drive/MyDrive/crane_maryland/predictions/project_2021_nov_13/jpgs/slope_20120203_17SQD1898_utm.jpg
# /content/drive/MyDrive/crane_maryland/predictions/project_2021_nov_13/jpgs/slope_20120203_17SQD2098_utm.jpg
# /content/drive/MyDrive/crane_maryland/predictions/project_2021_nov_13/jpgs/slope_20120203_17SQD2096_utm.jpg
# /content/drive/MyDrive/crane_maryland/predictions/project_2021_nov_13/jpgs/slope_20120203_17SQD2198_utm.jpg
# /content/drive/MyDrive/crane_maryland/predictions/project_2021_nov_13/jpgs/slope_20120203_17SQD2196_utm.jpg
# /content/drive/MyDrive/crane_maryland/predictions/project_2021_nov_13/jpgs/slope_20120203_17SQD2099_utm.jpg
# /content/drive/MyDrive/crane_maryland/predictions/project_2021_nov_13/jpgs/slope_20120203_17SQD2396_utm.jpg
# /content/drive/MyDrive/crane_maryland/predictions/project_2021_nov_13/jpgs/slope_20120203_17SQD2199_utm.jpg
# /content/drive/MyDrive/crane_maryland/predictions/project_2021_nov_13/jpgs/slope_20120203_17SQD2399_utm.jpg
# /content/drive/MyDrive/crane_maryland/predictions/project_2021_nov_13/jpgs/slope_20120203_17SQD2398_utm.jpg
# /content/drive/MyDrive/crane_maryland/predictions/project_2021_nov_13/jpgs/slope_20120203_17SQD2696_utm.jpg
# /content/drive/MyDrive/crane_maryland/predictions/project_2021_nov_13/jpgs/slope_20120203_17SQD2698_utm.jpg
# /content/drive/MyDrive/crane_maryland/predictions/project_2021_nov_13/jpgs/slope_20120203_17SQD2699_utm.jpg
# /content/drive/MyDrive/crane_maryland/predictions/project_2021_nov_13/jpgs/slope_20120203_17SQD2798_utm.jpg
# /content/drive/MyDrive/crane_maryland/predictions/project_2021_nov_13/jpgs/slope_20120203_17SQD2796_utm.jpg
# /content/drive/MyDrive/crane_maryland/predictions/project_2021_nov_13/jpgs/slope_20120203_17SQE0301_utm.jpg
# /content/drive/MyDrive/crane_maryland/predictions/project_2021_nov_13/jpgs/slope_20120203_17SQE0201_utm.jpg
# /content/drive/MyDrive/crane_maryland/predictions/project_2021_nov_13/jpgs/slope_20120203_17SQD2799_utm.jpg
# /content/drive/MyDrive/crane_maryland/predictions/project_2021_nov_13/jpgs/slope_20120203_17SQE1801_utm.jpg
# /content/drive/MyDrive/crane_maryland/predictions/project_2021_nov_13/jpgs/slope_20120203_17SQE1701_utm.jpg
# /content/drive/MyDrive/crane_maryland/predictions/project_2021_nov_13/jpgs/slope_20120203_17SQE0501_utm.jpg
# /content/drive/MyDrive/crane_maryland/predictions/project_2021_nov_13/jpgs/slope_20120203_17SQE2101_utm.jpg
# /content/drive/MyDrive/crane_maryland/predictions/project_2021_nov_13/jpgs/slope_20120203_17SQE2001_utm.jpg
# /content/drive/MyDrive/crane_maryland/predictions/project_2021_nov_13/jpgs/slope_20120131_17SQD2384_utm.jpg
# /content/drive/MyDrive/crane_maryland/predictions/project_2021_nov_13/jpgs/slope_20120131_17SQD2093_utm.jpg
# /content/drive/MyDrive/crane_maryland/predictions/project_2021_nov_13/jpgs/slope_20120131_17SQD2793_utm.jpg
# /content/drive/MyDrive/crane_maryland/predictions/project_2021_nov_13/jpgs/slope_20120131_17SQD2492_utm.jpg
# /content/drive/MyDrive/crane_maryland/predictions/project_2021_nov_13/jpgs/slope_20120203_17SPE9901_utm.jpg
# /content/drive/MyDrive/crane_maryland/predictions/project_2021_nov_13/jpgs/slope_20120203_17SPD9795_utm.jpg
# /content/drive/MyDrive/crane_maryland/predictions/project_2021_nov_13/jpgs/slope_20120131_17SQD2795_utm.jpg
# /content/drive/MyDrive/crane_maryland/predictions/project_2021_nov_13/jpgs/slope_20120203_17SQD0096_utm.jpg
# /content/drive/MyDrive/crane_maryland/predictions/project_2021_nov_13/jpgs/slope_20120203_17SQD0095_utm.jpg
# /content/drive/MyDrive/crane_maryland/predictions/project_2021_nov_13/jpgs/slope_20120203_17SQD0399_utm.jpg
# /content/drive/MyDrive/crane_maryland/predictions/project_2021_nov_13/jpgs/slope_20120203_17SQD0398_utm.jpg
# /content/drive/MyDrive/crane_maryland/predictions/project_2021_nov_13/jpgs/slope_20120203_17SQD0898_utm.jpg
# /content/drive/MyDrive/crane_maryland/predictions/project_2021_nov_13/jpgs/slope_20120203_17SQD0598_utm.jpg
# /content/drive/MyDrive/crane_maryland/predictions/project_2021_nov_13/jpgs/slope_20120203_17SQD0596_utm.jpg
# /content/drive/MyDrive/crane_maryland/predictions/project_2021_nov_13/jpgs/slope_20120203_17SQD0996_utm.jpg
# /content/drive/MyDrive/crane_maryland/predictions/project_2021_nov_13/jpgs/slope_20120203_17SQD0899_utm.jpg
# /content/drive/MyDrive/crane_maryland/predictions/project_2021_nov_13/jpgs/slope_20120203_17SQD0999_utm.jpg
# /content/drive/MyDrive/crane_maryland/predictions/project_2021_nov_13/jpgs/slope_20120203_17SQD0998_utm.jpg
# /content/drive/MyDrive/crane_maryland/predictions/project_2021_nov_13/jpgs/slope_20120203_17SQD1299_utm.jpg
# /content/drive/MyDrive/crane_maryland/predictions/project_2021_nov_13/jpgs/slope_20120203_17SQD1298_utm.jpg
# /content/drive/MyDrive/crane_maryland/predictions/project_2021_nov_13/jpgs/slope_20120203_17SQD1499_utm.jpg
# /content/drive/MyDrive/crane_maryland/predictions/project_2021_nov_13/jpgs/slope_20120203_17SQD1498_utm.jpg
# /content/drive/MyDrive/crane_maryland/predictions/project_2021_nov_13/jpgs/slope_20120203_17SQD1496_utm.jpg

# %%
# Predict it for all the images
# Run Predict Config and Write Annot before running this cell.
cfg_name='cfg20200826T2315'
model_epoch='0016'
object_type = "charcoal_hearth_hill"

print("cfg_name:",cfg_name)

#For all of the jpegs, run prediction

#images_dir
# Run on all images - produce results for analysis.
# images_dir = '/content/drive/MyDrive/crane_maryland/tif/tif_tiles/jpgs'

# 2021 Nov 13
images_dir = '/content/drive/MyDrive/crane_maryland/predictions/project_2021_nov_13/jpgs/'

import os
from os import listdir
import skimage
import cv2
from xml.etree import ElementTree
from numpy import zeros
from numpy import asarray
from mrcnn.utils import Dataset
from mrcnn.visualize import display_instances
from mrcnn.utils import extract_bboxes
from mrcnn.config import Config
import mrcnn.model as modellib

# define the prediction configuration
class PredictionConfig(Config):
	# define the name of the configuration
	NAME = object_type+"_cfg" 
	# number of classes (background + class (charcoal hearth))
	NUM_CLASSES = 1 + 1
	# simplify GPU config
	GPU_COUNT = 1
	IMAGES_PER_GPU = 1

# create config
cfg = PredictionConfig()
# define the model

model = modellib.MaskRCNN(mode='inference', model_dir='/content/drive/MyDrive/MaskCNNhearths/code_and_working_data/charcoal_hearth_hill/model/', config=cfg)
print("Model loaded.")
# load model weights
model_path = '/content/drive/MyDrive/MaskCNNhearths/code_and_working_data/charcoal_hearth_hill/model/charcoal_hearth_hill_cfg20200826T2315/mask_rcnn_charcoal_hearth_hill_cfg_0016.h5'
#model_path = '/home/student/charcoal_hearth_hill/model/'+object_type+'_'+cfg_name+'/mask_rcnn_'+object_type+'_cfg_'+model_epoch+'.h5'
model.load_weights(model_path, by_name=True)

image_prediction_folder = '/content/drive/MyDrive/crane_maryland/predictions/project_2021_nov_13/'+cfg_name

image_for_prediction_folder = images_dir

if not os.path.exists(image_prediction_folder):
    os.mkdir(image_prediction_folder)
image_prediction_folder = image_prediction_folder+'/unknown/'
if not os.path.exists(image_prediction_folder):
    os.mkdir(image_prediction_folder)
    
    
#Store the results in XML    
class_names = [object_type,object_type,]


# find all images
for filename in listdir(images_dir):
    # extract image id
    image_id = filename[:-4]
    ext = filename[-4:]
    if(ext ==".jpg"):
        img_path = os.path.join(images_dir, filename)
        #ann_path = annotations_dir + image_id + '.xml'
        #print(image_id,img_path,ann_path)
        print(image_id,img_path)
    
        image = cv2.imread(img_path)
        #image = skimage.io.imread(os.path.join(image_for_prediction_folder, test_file_names[cn]))
        #print("shape:", image.shape)
        # Run detection

        results = model.detect([image], verbose=1)
        # Visualize results
        r = results[0]
        #print(r['rois'], class_names, r['scores'])
        #print(r['rois'][1],r['rois'][1][0],r['rois'][1][1],r['rois'][1][2],r['rois'][1][3])
        #image2= display_instances(image, r['rois'], r['masks'], r['class_ids'], 
        #class_names, r['scores'])
        obj_f_num = image_id
        refPts = []
    
        for rcn in range(0,len(r['rois'])):
            refPt = []
            refPtM = []
            refPtM.append(r['rois'][rcn][1])
            refPtM.append(r['rois'][rcn][0])
            refPt.append(refPtM)
            refPtM = []
            refPtM.append(r['rois'][rcn][3])
            refPtM.append(r['rois'][rcn][2])
            refPt.append(refPtM)
            refPts.append(refPt)
            #print(refPts)
        write_annot(class_names[0], image_prediction_folder, obj_f_num, filename, image_for_prediction_folder,image.shape[1],image.shape[0],image.shape[2], refPts,r['scores'])
print("The results are in: "+image_prediction_folder)
# Out:
# cfg_name: cfg20200826T2315
# hi
# hi2
# Re-starting from epoch 16
# slope_20120203_17SQD1896_utm /content/drive/MyDrive/crane_maryland/predictions/project_2021_nov_13/jpgs/slope_20120203_17SQD1896_utm.jpg
# Processing 1 images
# image                    shape: (1598, 1598, 3)       min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  103.10000  float64
# image_metas              shape: (1, 14)               min:    0.00000  max: 1598.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# slope_20120203_17SQD1799_utm /content/drive/MyDrive/crane_maryland/predictions/project_2021_nov_13/jpgs/slope_20120203_17SQD1799_utm.jpg
# Processing 1 images
# image                    shape: (1599, 1598, 3)       min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  113.10000  float64
# image_metas              shape: (1, 14)               min:    0.00000  max: 1599.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# slope_20120203_17SQD1596_utm /content/drive/MyDrive/crane_maryland/predictions/project_2021_nov_13/jpgs/slope_20120203_17SQD1596_utm.jpg
# Processing 1 images
# image                    shape: (1599, 1598, 3)       min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  118.10000  float64
# image_metas              shape: (1, 14)               min:    0.00000  max: 1599.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# slope_20120203_17SQD1899_utm /content/drive/MyDrive/crane_maryland/predictions/project_2021_nov_13/jpgs/slope_20120203_17SQD1899_utm.jpg
# Processing 1 images
# image                    shape: (1599, 1598, 3)       min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  132.10000  float64
# image_metas              shape: (1, 14)               min:    0.00000  max: 1599.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# slope_20120203_17SQD1898_utm /content/drive/MyDrive/crane_maryland/predictions/project_2021_nov_13/jpgs/slope_20120203_17SQD1898_utm.jpg
# Processing 1 images
# image                    shape: (1599, 1598, 3)       min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  135.10000  float64
# image_metas              shape: (1, 14)               min:    0.00000  max: 1599.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# slope_20120203_17SQD2098_utm /content/drive/MyDrive/crane_maryland/predictions/project_2021_nov_13/jpgs/slope_20120203_17SQD2098_utm.jpg
# Processing 1 images
# image                    shape: (1598, 1597, 3)       min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  113.10000  float64
# image_metas              shape: (1, 14)               min:    0.00000  max: 1598.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# slope_20120203_17SQD2096_utm /content/drive/MyDrive/crane_maryland/predictions/project_2021_nov_13/jpgs/slope_20120203_17SQD2096_utm.jpg
# Processing 1 images
# image                    shape: (1598, 1598, 3)       min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  128.10000  float64
# image_metas              shape: (1, 14)               min:    0.00000  max: 1598.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# slope_20120203_17SQD2198_utm /content/drive/MyDrive/crane_maryland/predictions/project_2021_nov_13/jpgs/slope_20120203_17SQD2198_utm.jpg
# Processing 1 images
# image                    shape: (1598, 1598, 3)       min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  115.10000  float64
# image_metas              shape: (1, 14)               min:    0.00000  max: 1598.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# slope_20120203_17SQD2196_utm /content/drive/MyDrive/crane_maryland/predictions/project_2021_nov_13/jpgs/slope_20120203_17SQD2196_utm.jpg
# Processing 1 images
# image                    shape: (1599, 1597, 3)       min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  116.10000  float64
# image_metas              shape: (1, 14)               min:    0.00000  max: 1599.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# slope_20120203_17SQD2099_utm /content/drive/MyDrive/crane_maryland/predictions/project_2021_nov_13/jpgs/slope_20120203_17SQD2099_utm.jpg
# Processing 1 images
# image                    shape: (1598, 1598, 3)       min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  114.10000  float64
# image_metas              shape: (1, 14)               min:    0.00000  max: 1598.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# slope_20120203_17SQD2396_utm /content/drive/MyDrive/crane_maryland/predictions/project_2021_nov_13/jpgs/slope_20120203_17SQD2396_utm.jpg
# Processing 1 images
# image                    shape: (1598, 1598, 3)       min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  131.10000  float64
# image_metas              shape: (1, 14)               min:    0.00000  max: 1598.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# slope_20120203_17SQD2199_utm /content/drive/MyDrive/crane_maryland/predictions/project_2021_nov_13/jpgs/slope_20120203_17SQD2199_utm.jpg
# Processing 1 images
# image                    shape: (1599, 1598, 3)       min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  109.10000  float64
# image_metas              shape: (1, 14)               min:    0.00000  max: 1599.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# slope_20120203_17SQD2399_utm /content/drive/MyDrive/crane_maryland/predictions/project_2021_nov_13/jpgs/slope_20120203_17SQD2399_utm.jpg
# Processing 1 images
# image                    shape: (1598, 1597, 3)       min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  137.10000  float64
# image_metas              shape: (1, 14)               min:    0.00000  max: 1598.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# slope_20120203_17SQD2398_utm /content/drive/MyDrive/crane_maryland/predictions/project_2021_nov_13/jpgs/slope_20120203_17SQD2398_utm.jpg
# Processing 1 images
# image                    shape: (1599, 1597, 3)       min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:   92.10000  float64
# image_metas              shape: (1, 14)               min:    0.00000  max: 1599.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# slope_20120203_17SQD2696_utm /content/drive/MyDrive/crane_maryland/predictions/project_2021_nov_13/jpgs/slope_20120203_17SQD2696_utm.jpg
# Processing 1 images
# image                    shape: (1599, 1598, 3)       min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  115.10000  float64
# image_metas              shape: (1, 14)               min:    0.00000  max: 1599.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# slope_20120203_17SQD2698_utm /content/drive/MyDrive/crane_maryland/predictions/project_2021_nov_13/jpgs/slope_20120203_17SQD2698_utm.jpg
# Processing 1 images
# image                    shape: (1598, 1598, 3)       min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  122.10000  float64
# image_metas              shape: (1, 14)               min:    0.00000  max: 1598.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# slope_20120203_17SQD2699_utm /content/drive/MyDrive/crane_maryland/predictions/project_2021_nov_13/jpgs/slope_20120203_17SQD2699_utm.jpg
# Processing 1 images
# image                    shape: (1599, 1598, 3)       min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  130.10000  float64
# image_metas              shape: (1, 14)               min:    0.00000  max: 1599.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# slope_20120203_17SQD2798_utm /content/drive/MyDrive/crane_maryland/predictions/project_2021_nov_13/jpgs/slope_20120203_17SQD2798_utm.jpg
# Processing 1 images
# image                    shape: (1598, 1598, 3)       min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  113.10000  float64
# image_metas              shape: (1, 14)               min:    0.00000  max: 1598.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# slope_20120203_17SQD2796_utm /content/drive/MyDrive/crane_maryland/predictions/project_2021_nov_13/jpgs/slope_20120203_17SQD2796_utm.jpg
# Processing 1 images
# image                    shape: (1598, 1598, 3)       min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  128.10000  float64
# image_metas              shape: (1, 14)               min:    0.00000  max: 1598.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# slope_20120203_17SQE0301_utm /content/drive/MyDrive/crane_maryland/predictions/project_2021_nov_13/jpgs/slope_20120203_17SQE0301_utm.jpg
# Processing 1 images
# image                    shape: (967, 1560, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  145.10000  float64
# image_metas              shape: (1, 14)               min:    0.00000  max: 1560.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# slope_20120203_17SQE0201_utm /content/drive/MyDrive/crane_maryland/predictions/project_2021_nov_13/jpgs/slope_20120203_17SQE0201_utm.jpg
# Processing 1 images
# image                    shape: (938, 1556, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  144.10000  float64
# image_metas              shape: (1, 14)               min:    0.00000  max: 1556.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# slope_20120203_17SQD2799_utm /content/drive/MyDrive/crane_maryland/predictions/project_2021_nov_13/jpgs/slope_20120203_17SQD2799_utm.jpg
# Processing 1 images
# image                    shape: (1599, 1598, 3)       min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  141.10000  float64
# image_metas              shape: (1, 14)               min:    0.00000  max: 1599.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# slope_20120203_17SQE1801_utm /content/drive/MyDrive/crane_maryland/predictions/project_2021_nov_13/jpgs/slope_20120203_17SQE1801_utm.jpg
# Processing 1 images
# image                    shape: (1388, 1588, 3)       min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  149.10000  float64
# image_metas              shape: (1, 14)               min:    0.00000  max: 1588.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# slope_20120203_17SQE1701_utm /content/drive/MyDrive/crane_maryland/predictions/project_2021_nov_13/jpgs/slope_20120203_17SQE1701_utm.jpg
# Processing 1 images
# image                    shape: (1400, 1584, 3)       min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  150.10000  float64
# image_metas              shape: (1, 14)               min:    0.00000  max: 1584.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# slope_20120203_17SQE0501_utm /content/drive/MyDrive/crane_maryland/predictions/project_2021_nov_13/jpgs/slope_20120203_17SQE0501_utm.jpg
# Processing 1 images
# image                    shape: (1037, 1563, 3)       min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  148.10000  float64
# image_metas              shape: (1, 14)               min:    0.00000  max: 1563.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# slope_20120203_17SQE2101_utm /content/drive/MyDrive/crane_maryland/predictions/project_2021_nov_13/jpgs/slope_20120203_17SQE2101_utm.jpg
# Processing 1 images
# image                    shape: (1547, 1597, 3)       min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  140.10000  float64
# image_metas              shape: (1, 14)               min:    0.00000  max: 1597.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# slope_20120203_17SQE2001_utm /content/drive/MyDrive/crane_maryland/predictions/project_2021_nov_13/jpgs/slope_20120203_17SQE2001_utm.jpg
# Processing 1 images
# image                    shape: (1468, 1594, 3)       min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  148.10000  float64
# image_metas              shape: (1, 14)               min:    0.00000  max: 1594.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# slope_20120131_17SQD2384_utm /content/drive/MyDrive/crane_maryland/predictions/project_2021_nov_13/jpgs/slope_20120131_17SQD2384_utm.jpg
# Processing 1 images
# image                    shape: (1598, 1598, 3)       min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  114.10000  float64
# image_metas              shape: (1, 14)               min:    0.00000  max: 1598.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# slope_20120131_17SQD2093_utm /content/drive/MyDrive/crane_maryland/predictions/project_2021_nov_13/jpgs/slope_20120131_17SQD2093_utm.jpg
# Processing 1 images
# image                    shape: (1598, 1598, 3)       min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  142.10000  float64
# image_metas              shape: (1, 14)               min:    0.00000  max: 1598.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# slope_20120131_17SQD2793_utm /content/drive/MyDrive/crane_maryland/predictions/project_2021_nov_13/jpgs/slope_20120131_17SQD2793_utm.jpg
# Processing 1 images
# image                    shape: (1598, 1598, 3)       min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  144.10000  float64
# image_metas              shape: (1, 14)               min:    0.00000  max: 1598.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# slope_20120131_17SQD2492_utm /content/drive/MyDrive/crane_maryland/predictions/project_2021_nov_13/jpgs/slope_20120131_17SQD2492_utm.jpg
# Processing 1 images
# image                    shape: (1598, 1598, 3)       min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  132.10000  float64
# image_metas              shape: (1, 14)               min:    0.00000  max: 1598.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# slope_20120203_17SPE9901_utm /content/drive/MyDrive/crane_maryland/predictions/project_2021_nov_13/jpgs/slope_20120203_17SPE9901_utm.jpg
# Processing 1 images
# image                    shape: (1329, 1585, 3)       min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  123.10000  float64
# image_metas              shape: (1, 14)               min:    0.00000  max: 1585.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# slope_20120203_17SPD9795_utm /content/drive/MyDrive/crane_maryland/predictions/project_2021_nov_13/jpgs/slope_20120203_17SPD9795_utm.jpg
# Processing 1 images
# image                    shape: (1599, 1599, 3)       min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  129.10000  float64
# image_metas              shape: (1, 14)               min:    0.00000  max: 1599.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# slope_20120131_17SQD2795_utm /content/drive/MyDrive/crane_maryland/predictions/project_2021_nov_13/jpgs/slope_20120131_17SQD2795_utm.jpg
# Processing 1 images
# image                    shape: (1598, 1598, 3)       min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  141.10000  float64
# image_metas              shape: (1, 14)               min:    0.00000  max: 1598.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# slope_20120203_17SQD0096_utm /content/drive/MyDrive/crane_maryland/predictions/project_2021_nov_13/jpgs/slope_20120203_17SQD0096_utm.jpg
# Processing 1 images
# image                    shape: (1599, 1598, 3)       min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  102.10000  float64
# image_metas              shape: (1, 14)               min:    0.00000  max: 1599.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# slope_20120203_17SQD0095_utm /content/drive/MyDrive/crane_maryland/predictions/project_2021_nov_13/jpgs/slope_20120203_17SQD0095_utm.jpg
# Processing 1 images
# image                    shape: (1599, 1598, 3)       min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  116.10000  float64
# image_metas              shape: (1, 14)               min:    0.00000  max: 1599.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# slope_20120203_17SQD0399_utm /content/drive/MyDrive/crane_maryland/predictions/project_2021_nov_13/jpgs/slope_20120203_17SQD0399_utm.jpg
# Processing 1 images
# image                    shape: (1599, 1598, 3)       min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  144.10000  float64
# image_metas              shape: (1, 14)               min:    0.00000  max: 1599.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# slope_20120203_17SQD0398_utm /content/drive/MyDrive/crane_maryland/predictions/project_2021_nov_13/jpgs/slope_20120203_17SQD0398_utm.jpg
# Processing 1 images
# image                    shape: (1599, 1598, 3)       min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  146.10000  float64
# image_metas              shape: (1, 14)               min:    0.00000  max: 1599.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# slope_20120203_17SQD0898_utm /content/drive/MyDrive/crane_maryland/predictions/project_2021_nov_13/jpgs/slope_20120203_17SQD0898_utm.jpg
# Processing 1 images
# image                    shape: (1599, 1598, 3)       min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  135.10000  float64
# image_metas              shape: (1, 14)               min:    0.00000  max: 1599.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# slope_20120203_17SQD0598_utm /content/drive/MyDrive/crane_maryland/predictions/project_2021_nov_13/jpgs/slope_20120203_17SQD0598_utm.jpg
# Processing 1 images
# image                    shape: (1599, 1598, 3)       min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  138.10000  float64
# image_metas              shape: (1, 14)               min:    0.00000  max: 1599.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# slope_20120203_17SQD0596_utm /content/drive/MyDrive/crane_maryland/predictions/project_2021_nov_13/jpgs/slope_20120203_17SQD0596_utm.jpg
# Processing 1 images
# image                    shape: (1599, 1598, 3)       min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  109.10000  float64
# image_metas              shape: (1, 14)               min:    0.00000  max: 1599.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# slope_20120203_17SQD0996_utm /content/drive/MyDrive/crane_maryland/predictions/project_2021_nov_13/jpgs/slope_20120203_17SQD0996_utm.jpg
# Processing 1 images
# image                    shape: (1598, 1598, 3)       min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  134.10000  float64
# image_metas              shape: (1, 14)               min:    0.00000  max: 1598.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# slope_20120203_17SQD0899_utm /content/drive/MyDrive/crane_maryland/predictions/project_2021_nov_13/jpgs/slope_20120203_17SQD0899_utm.jpg
# Processing 1 images
# image                    shape: (1599, 1598, 3)       min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  132.10000  float64
# image_metas              shape: (1, 14)               min:    0.00000  max: 1599.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# slope_20120203_17SQD0999_utm /content/drive/MyDrive/crane_maryland/predictions/project_2021_nov_13/jpgs/slope_20120203_17SQD0999_utm.jpg
# Processing 1 images
# image                    shape: (1599, 1598, 3)       min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  141.10000  float64
# image_metas              shape: (1, 14)               min:    0.00000  max: 1599.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# slope_20120203_17SQD0998_utm /content/drive/MyDrive/crane_maryland/predictions/project_2021_nov_13/jpgs/slope_20120203_17SQD0998_utm.jpg
# Processing 1 images
# image                    shape: (1599, 1599, 3)       min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  116.10000  float64
# image_metas              shape: (1, 14)               min:    0.00000  max: 1599.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# slope_20120203_17SQD1299_utm /content/drive/MyDrive/crane_maryland/predictions/project_2021_nov_13/jpgs/slope_20120203_17SQD1299_utm.jpg
# Processing 1 images
# image                    shape: (1599, 1598, 3)       min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:   89.10000  float64
# image_metas              shape: (1, 14)               min:    0.00000  max: 1599.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# slope_20120203_17SQD1298_utm /content/drive/MyDrive/crane_maryland/predictions/project_2021_nov_13/jpgs/slope_20120203_17SQD1298_utm.jpg
# Processing 1 images
# image                    shape: (1599, 1598, 3)       min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  135.10000  float64
# image_metas              shape: (1, 14)               min:    0.00000  max: 1599.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# slope_20120203_17SQD1499_utm /content/drive/MyDrive/crane_maryland/predictions/project_2021_nov_13/jpgs/slope_20120203_17SQD1499_utm.jpg
# Processing 1 images
# image                    shape: (1598, 1598, 3)       min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  119.10000  float64
# image_metas              shape: (1, 14)               min:    0.00000  max: 1598.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# slope_20120203_17SQD1498_utm /content/drive/MyDrive/crane_maryland/predictions/project_2021_nov_13/jpgs/slope_20120203_17SQD1498_utm.jpg
# Processing 1 images
# image                    shape: (1598, 1598, 3)       min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  110.10000  float64
# image_metas              shape: (1, 14)               min:    0.00000  max: 1598.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# slope_20120203_17SQD1496_utm /content/drive/MyDrive/crane_maryland/predictions/project_2021_nov_13/jpgs/slope_20120203_17SQD1496_utm.jpg
# Processing 1 images
# image                    shape: (1599, 1598, 3)       min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  133.10000  float64
# image_metas              shape: (1, 14)               min:    0.00000  max: 1599.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# The results are in: /content/drive/MyDrive/crane_maryland/predictions/project_2021_nov_13/cfg20200826T2315/unknown/

# %%
        image = cv2.imread('/content/drive/MyDrive/crane_maryland/predictions/project_2021_nov_13/slope_tifs/slope_20120203_17SQD1896_utm.tif')
        #image = skimage.io.imread(os.path.join(image_for_prediction_folder, test_file_names[cn]))
        #print("shape:", image.shape)
        # Run detection
        print(image)

        results = model.detect([image], verbose=1)
# Out:
# None
# Processing 1 images
# image
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-13-4df72c7d0c93> in <module>()
#       5 print(image)
#       6
# ----> 7 results = model.detect([image], verbose=1)
#
# /content/drive/MyDrive/crane_maryland/mask-rcnn-repository/Mask_RCNN/mrcnn/model.py in detect(self, images, verbose)
#    2501
#    2502         # Mold inputs to format expected by the neural network
# -> 2503         molded_images, image_metas, windows = self.mold_inputs(images)
#    2504
#    2505         # Validate image sizes
#
# /content/drive/MyDrive/crane_maryland/mask-rcnn-repository/Mask_RCNN/mrcnn/model.py in mold_inputs(self, images)
#    2399                 min_scale=self.config.IMAGE_MIN_SCALE,
#    2400                 max_dim=self.config.IMAGE_MAX_DIM,
# -> 2401                 mode=self.config.IMAGE_RESIZE_MODE)
#    2402             molded_image = mold_image(molded_image, self.config)
#    2403             # Build image_meta
#
# /content/drive/MyDrive/crane_maryland/mask-rcnn-repository/Mask_RCNN/mrcnn/utils.py in resize_image(image, min_dim, max_dim, min_scale, mode)
#     419     """
#     420     # Keep track of image dtype and return results in the same dtype
# --> 421     image_dtype = image.dtype
#     422     # Default window (y1, x1, y2, x2) and default scale == 1.
#     423     h, w = image.shape[:2]
#
# AttributeError: 'NoneType' object has no attribute 'dtype'

# %%
import os
from os import listdir
import cv2
import skimage
from xml.etree import ElementTree
from numpy import zeros
from numpy import asarray
from google.colab.patches import cv2_imshow
from matplotlib import pyplot
from matplotlib.pyplot import figure

#coordinate = "0106"
#training_image = '/content/drive/MyDrive/crane_ane/data/images/jpgs/401'+coordinate +'.jpg'
#prediction_annot_file_path = '/content/drive/MyDrive/MaskCNNhearths/code_and_working_data/charcoal_hearth_hill/predictions/cfg20200826T2315/unknown/401'+coordinate +'.xml'

prediction_image_folder = '/content/drive/MyDrive/crane_maryland/tif/tif_tiles/jpgs/'
prediction_annot_folder = '/content/drive/MyDrive/crane_maryland/predictions/cfg20200826T2315/unknown'

training_annot_file_path = ""

font = cv2.FONT_HERSHEY_SIMPLEX 
font_scale = 1
font_color = (0, 200, 0) 
font_thickness = 2

for prediction_image in listdir(prediction_image_folder):
    print(prediction_image)
    annotation_file = prediction_image[:-4]+".xml"
    image = cv2.imread(os.path.join(prediction_image_folder,prediction_image))
    print(image.shape)
    prediction_annot_file_path = os.path.join(prediction_annot_folder,annotation_file)

    overlay = image.copy()
    output = image.copy()
    #cv2_imshow(output)    
    font_color = (255, 0, 255)
    font_scale = .6
    font_thickness = 1

    print(prediction_annot_file_path)
    if(os.path.exists(prediction_annot_file_path)):
        tree_train = ElementTree.parse(prediction_annot_file_path)
        root_train = tree_train.getroot()
        for obj in root_train.findall('./object'):
            box = obj.find('bndbox')
            xmin = int(box.find('xmin').text)
            ymin = int(box.find('ymin').text)
            xmax = int(box.find('xmax').text)
            ymax = int(box.find('ymax').text)
            box_num = str(obj.find('number').text)
            score = float(obj.find('score').text)
            if(ymin>ymax):
                ytemp = ymin
                ymin = ymax
                ymax=ytemp
            if(xmin>xmax):
                xtemp = xmin
                xmin = xmax
                xmax=xtemp            
            coors = [xmin, ymin, xmax, ymax]
            crop_output = output[ymin:ymax, xmin:xmax]
        
            cv2.rectangle(output, (xmin, ymin), (xmax, ymax),(255, 0, 255), 2)
            cv2.putText(output, f'{score:.3f}' , (xmin+0, ymin-17), font, font_scale, font_color, font_thickness, cv2.LINE_AA)
        print(root_train.findall('./object'))
        objs = root_train.findall('./object')
        if(len(objs)>0):
            cv2_imshow(output)
    else:
        print("No prediction annotation file for this image.  This is likely ok.")




#crop_output = output[ymin:ymax, xmin:xmax]
#resized = cv2.resize(output, (64, 30))
